# %% [markdown]
# # Data Wrangling with MongoDB - Project 3
#
# I choose the Raleigh city in North Carolina to work on for this project on data wrangeling with MongoDB.

# %% [markdown]
# ##  Import modules to start with parsing the data

# %%
# Importing necessary python modules
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import collections
import pymongo

# %%
osm_file = open("raleigh_north-carolina.osm",'r')

# %% [markdown]
# ## Data Audit
#
# Let us parse through the data using ElementTree iteratevly to see how many unique elements there are in the dataset to an overview understanding of the data.

# %%
# parsing through the dataset iteratvely to find unique elements in the dataset
def count_tags(filename):
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag in tags: 
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags

# %%
# Call the function count-tags on the Chicago dataset
tags_raleigh = count_tags('raleigh_north-carolina.osm')
pprint.pprint(tags_raleigh)
# Out:
# {'bounds': 1,
#  'member': 8684,
#  'nd': 2622994,
#  'node': 2325555,
#  'osm': 1,
#  'relation': 889,
#  'tag': 886324,
#  'way': 238794}

# %% [markdown]
# Before  processing the data and add it into a database, we should check the "k" value for each "<tag>" (there are 886,324 tag elements in the dataset as showen in the above result) and see if there are any potential problems.
# We define  'key_type' & 'process_map' functions that check the "k" value for each tag.The 'key_type'provides a count of each of three tag categories in a dictionary: "lower", for tags that contain only lowercase letters and are valid, "lower_colon", for valid tags with a colon in their names, "problemchars", for tags with problematic characters.

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
raleigh_keys = process_map('raleigh_north-carolina.osm')
pprint.pprint(raleigh_keys)
# Out:
# {'lower': 552793, 'lower_colon': 290466, 'other': 43063, 'problemchars': 2}

# %% [markdown]
# Let us look at the number of  unique users that have contributed to the city map of Raleigh,NC.The result below diplay that there are 952 uniques users who has contributed to this.

# %%
#people invovlved in the map editing.
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for ele in element:
            if 'uid' in ele.attrib:
                users.add(ele.attrib['uid'])
    return users
users = process_map('raleigh_north-carolina.osm')
len(users)
# Out:
# 952

# %% [markdown]
# # Probelms in the Dataset

# %% [markdown]
# ## Audit Street Names
#
# Most of the problem in this data set is name inconsitency of street addresses. They street names consits of inconsitent abberevations. The following code use regular expression to match the very last of the street name as most street names end with street types like Avenue, Street, Road etc. And adds the street names that is not conistent with most comment street names which are listed in 'expected' list below to a set-'street_types'.

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Avenue", "Boulevard", "Commons", "Court", "Drive", "Lane", "Parkway", 
                         "Place", "Road", "Square", "Street", "Trail"]

mapping = {'Ave'  : 'Avenue',
           'Blvd' : 'Boulevard',
           'Dr'   : 'Drive',
           'Dr.'  : 'Drive',
           'Blvd.': 'Boulevard',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Pky'  : 'Parkway',
           'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'St'   : 'Street',
           'St,'  : 'Street',
           'street' :"Street",
           'Ct'   : "Court",
           'Cir'  : "Circle",
           'Cr'   : "Court",
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Sq'   : "Square"}

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# %% [markdown]
# - audit_street_type function search the input string for the regex. If there is a match and it is not within the "expected" list, add the match as a key and add the string to the set.
# - is_street_name function looks at the attribute k if k="addre:street"
# - audit functio will return the list that match previous two functions. After that, we would do a pretty print the output of the audit. With the list of all the abbreviated street types we can understand and fill-up our "mapping" dictionary as a preparatio to convert these street name into proper form.

# %%
streettypes_raleigh = audit('raleigh_north-carolina.osm')

# %% [markdown]
# We then take a brief look at the unclean street name using pretty print below

# %%
pprint.pprint(dict(streettypes_raleigh))
# Out:
# {'100': set(['100', 'Westgate Park Dr #100']),
#  '1000': set(['Six Forks Road #1000']),
#  '102': set(['Page Rd #102']),
#  '1100': set(['Fayetteville St #1100']),
#  '112': set(['Lynn Road #112']),
#  '115': set(['Brier Creek Pkwy #115']),
#  '17': set(['US Highway 17']),
#  '206': set(['Barrett Dr Suite 206']),
#  '27604-2428': set(['27604-2428']),
#  '27609': set(['27609']),
#  '27609-5360': set(['27609-5360']),
#  '315': set(['Kildaire Farm Road #315']),
#  '501': set(['US 15;US 501']),
#  '54': set(['Highway 54',
#             'State Highway 54',
#             'West Highway 54',
#             'West NC Highway 54',
#             'West State Highway 54']),
#  '55': set(['Highway 55', 'NC Highway 55', 'US 55']),
#  '70': set(['US 70']),
#  '751': set(['NC 751', 'NC Highway 751']),
#  'Alley': set(['Yates Motor Company Alley']),
#  'Ave': set(['Atlantic Ave',
#              'E. Winmore Ave',
#              'East Winmore Ave',
#              'Glenwood Ave',
#              'Mountford Ave',
#              'N Harrison Ave',
#              'North Harrison Ave',
#              'S Boylan Ave',
#              'S. Boylan Ave']),
#  'Blvd': set(['Airport Blvd',
#               'Capital Blvd',
#               'Fordham Blvd',
#               'Lake Grove Blvd',
#               'Martin Luther King Jr Blvd',
#               'Martin Luther King Jr. Blvd',
#               'Martin Luther King Junior Blvd',
#               'Southpoint Autopark Blvd',
#               'Witherspoon Blvd']),
#  'Blvd.': set(['Durham-Chapel Hill Blvd.',
#                'N Fordham Blvd.',
#                'Southpoint Auto Park Blvd.']),
#  'Bypass': set(['Highway 54 Bypass', 'US 15 501 Bypass']),
#  'CIrcle': set(['Meadowmont Village CIrcle']),
#  'Chatham': set(['East Chatham']),
#  'Cir': set(['Braddock Cir', 'Daybrook Cir']),
#  'Circle': set(['Alliance Circle',
#                 'Arrow Leaf Circle',
#                 'Barriedale Circle',
#                 'Broyhill Circle',
#                 'Cottonwood Circle',
#                 'Croatan Circle',
#                 'Davie Circle',
#                 'Davis Circle',
#                 'Davis Grove Circle',
#                 'Duck Pond Circle',
#                 'Duke Medicine Circle',
#                 'Euphoria Circle',
#                 'Glen Alpine Circle',
#                 'Golden Horseshoe Circle',
#                 'Hayloft Circle',
#                 'Kevin Circle',
#                 'Kintyre Circle',
#                 'Lake Hollow Circle',
#                 'Langley Circle',
#                 'Meadowmont Village Circle',
#                 'Meadowvale Circle',
#                 'Medallion Circle',
#                 'Mount Rogers Circle',
#                 'Noblewood Circle',
#                 'Northwood Circle',
#                 'Page Point Circle',
#                 'Parkbrook Circle',
#                 'Parkleaf Circle',
#                 'Parkmist Circle',
#                 'Parkmount Circle',
#                 'Parkvine Circle',
#                 'Penley Circle',
#                 'Phaeton Circle',
#                 'Pine Top Circle',
#                 'Piper Stream Circle',
#                 'Quarrystone Circle',
#                 'Ravens Point Circle',
#                 'Redbud Circle',
#                 'Redwood Circle',
#                 'Ricky Circle',
#                 'Rockland Circle',
#                 'Shady Meadow Circle',
#                 'Sunset Creek Circle',
#                 'Talton Circle',
#                 'Tartan Circle',
#                 'Trillium Circle',
#                 'Viewpoint Circle']),
#  'Crescent': set(['West Acres Crescent']),
#  'Crossing': set(['Oldham Forest Crossing']),
#  'Ct': set(['Ashley Springs Ct',
#             'Bevel Ct',
#             'Braidwood Ct',
#             'Crawford Ct',
#             'Gulf Ct']),
#  'Dr': set(['Calabria Dr',
#             'Colonnade Center Dr',
#             'Crab Orchard Dr',
#             'Gold Star Dr',
#             'Grande Heights Dr',
#             'Kentington Dr',
#             'Sablewood Dr',
#             'Stinson Dr',
#             'Triangle Plantation Dr',
#             'University Dr',
#             'Waterford Lake Dr',
#             'Westgate Dr']),
#  'Dr.': set(['Davis Dr.']),
#  'Driver': set(['Garrett Driver']),
#  'E': set(['Garner Rd Ste E']),
#  'East': set(['US Highway 70 East']),
#  'Ext': set(['New Hope Commons Boulevard Ext', 'Pritchard Avenue Ext']),
#  'Extension': set(['Weaver Dairy Road Extension']),
#  'Fork': set(['Dry Fork']),
#  'Grove': set(['Newton Grove']),
#  'Hall': set(['Carroll Hall']),
#  'Highway': set(['Apex Highway', 'NC 54 Highway', 'Wake Forest Highway']),
#  'Hill': set(['Chapel Hill']),
#  'Hills': set(['The Circle at North Hills']),
#  'L6': set(['Autumn Hill Terrace #L6']),
#  'LaurelcherryStreet': set(['LaurelcherryStreet']),
#  'Ln': set(['Bass Pro Ln', 'Springerly Ln', 'Sunbow Falls Ln']),
#  'Loop': set(['Amiable Loop', 'Beckingham Loop', 'Farrow Glen Loop']),
#  'PI': set(['Alexander Promenade PI']),
#  'Pkwy': set(['McCrimmon Pkwy', 'Skyland Ridge Pkwy']),
#  'Pky': set(['Brier Creek Pky', 'brier Creek Pky']),
#  'Pl': set(['Balaji Pl']),
#  'Plaza': set(['City Hall Plaza', 'Exchange Plaza', 'Park Forty Plaza']),
#  'Point': set(['Rocky Point']),
#  'Practice': set(['Triangle Family Practice']),
#  'Rd': set(['Blue Ridge Rd',
#             'Buck Jones Rd',
#             'Chapel Hill Rd',
#             'Creedmoor Rd',
#             'Falls of Neuse Rd',
#             'N Roxboro Rd',
#             'SW Maynard Rd',
#             'Six Forks Rd',
#             'Trinity Rd']),
#  'Rd.': set(['Bayleaf Church Rd.', 'Chapel Hill Rd.', 'Hillandale Rd.']),
#  'Ridge': set(['Vilana Ridge']),
#  'Run': set(['Deep Gap Run', 'Morgans Corner Run']),
#  'ST': set(['W EDENTON ST']),
#  'St': set(['9th St',
#             'E Chatham St',
#             'Hillsborough St',
#             'Holloway St',
#             'Kinsey St',
#             'Main at North Hills St',
#             'S Gregson St',
#             'S Roxboro St',
#             'S Wilmington St',
#             'W Franklin St',
#             'W Geer St',
#             'W Peace St']),
#  'St,': set(['Morris St,']),
#  'St.': set(['E Rosemary St.',
#              'East Corcoran St.',
#              'East Franklin St.',
#              'W Rosemary St.',
#              'W. Franklin St.',
#              'W. Pettigrew St.',
#              'West Rosemary St.']),
#  'Terrace': set(['Crestgate Terrace', 'Stonebrook Terrace', 'Vernon Terrace']),
#  'Way': set(['Anson Way',
#              'Attmore Way',
#              'Augustus Merrimon Way',
#              'Bergeron Way',
#              'Boulderstone Way',
#              'Bright Beginning Way',
#              'Bromfield Way',
#              'Brook Fern Way',
#              'Bullybunion Way',
#              'Burgwin Wright Way',
#              'Calebra Way',
#              'Centre Green Way',
#              'Chessridge Way',
#              'Cupola Chase Way',
#              'Drystack Way',
#              'Duncan Vale Way',
#              'Endeavor Way',
#              'Environ Way',
#              'Glebe Way',
#              'Graywick Way',
#              'Heck Andrews Way',
#              'Hill Hollow Way',
#              'Holsten Bank Way',
#              'Initiative Way',
#              'Katahdin Way',
#              'Kate Denson Way',
#              'Kenwyck Manor Way',
#              'Lathbury Landing Way',
#              'Leacroft Way',
#              'Ledgestone Way',
#              'Lone Star Way',
#              'Lothian Way',
#              'Lower Shiloh Way',
#              'Marlborough Way',
#              'Mentone Way',
#              'Michaels Way',
#              'Montclair Way',
#              'Morrisville Square Way',
#              'Mt Pisgah Way',
#              'Natalie Brook Way',
#              'Newington Hills Way',
#              'Olde Weatherstone Way',
#              'Partners Way',
#              'Passaic Way',
#              'Plank Bridge Way',
#              'Pond Glen Way',
#              'Rossburn Way',
#              'Sorrell Brook Way',
#              'Talisman Way',
#              'Thendara Way',
#              'Trent Woods Way',
#              'Union Mills Way',
#              'Winifred Way',
#              'Wolf Village Way',
#              'Wyatt Brook Way',
#              'Zaldivar Way']),
#  'West': set(['Columbia Place West',
#               'Highway 54 West',
#               'Highway 55 West',
#               'Highway West',
#               'NC Highway 55 West'])}

# %% [markdown]
# - audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix
#     the unexpected street types to the appropriate ones in the expected list.
#     You have to add mappings only for the actual problems you find in this OSMFILE,
#     not a generalized solution, since that may and will depend on the particular area you are auditing.
# - write the update_name function, to actually fix the street name.
#     The function takes a string with street name as an argument and should return the fixed name
# This last function update_name is the last step of the process, which take the old name and update them with a better name

# %%
def update_name(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)

    return name

for street_type, ways in streettypes_raleigh.iteritems():
    for name in ways:
        better_name = update_name(name, mapping, street_type_re)
        print name, "=>", better_name
if name == 'Blue Ridge Rd':
    assert better_name == 'Blue Ridge Road'
if name == 'Chapel Hill Rd':
    assert better_name == 'Chapel Hill Road'
# Out:
# Oldham Forest Crossing => Oldham Forest Crossing
# The Circle at North Hills => The Circle at North Hills
# Morris St, => Morris Street
# NC Highway 55 West => NC Highway 55 West
# Highway 54 West => Highway 54 West
# Highway 55 West => Highway 55 West
# Highway West => Highway West
# Columbia Place West => Columbia Place West
# E Rosemary St. => E Rosemary St.
# East Franklin St. => East Franklin St.
# W. Franklin St. => W. Franklin St.
# West Rosemary St. => West Rosemary St.
# East Corcoran St. => East Corcoran St.
# W Rosemary St. => W Rosemary St.
# W. Pettigrew St. => W. Pettigrew St.
# Lynn Road #112 => Lynn Road #112
# Kildaire Farm Road #315 => Kildaire Farm Road #315
# Buck Jones Rd => Buck Jones Road
# Falls of Neuse Rd => Falls of Neuse Road
# Chapel Hill Rd => Chapel Hill Road
# Blue Ridge Rd => Blue Ridge Road
# Six Forks Rd => Six Forks Road
# N Roxboro Rd => N Roxboro Road
# Trinity Rd => Trinity Road
# Creedmoor Rd => Creedmoor Road
# SW Maynard Rd => SW Maynard Road
# 27609 => 27609
# Chapel Hill => Chapel Hill
# Katahdin Way => Katahdin Way
# Duncan Vale Way => Duncan Vale Way
# Lathbury Landing Way => Lathbury Landing Way
# Bromfield Way => Bromfield Way
# Montclair Way => Montclair Way
# Anson Way => Anson Way
# Ledgestone Way => Ledgestone Way
# Union Mills Way => Union Mills Way
# Lone Star Way => Lone Star Way
# Kenwyck Manor Way => Kenwyck Manor Way
# Burgwin Wright Way => Burgwin Wright Way
# Bullybunion Way => Bullybunion Way
# Kate Denson Way => Kate Denson Way
# Drystack Way => Drystack Way
# Rossburn Way => Rossburn Way
# Mentone Way => Mentone Way
# Wyatt Brook Way => Wyatt Brook Way
# Newington Hills Way => Newington Hills Way
# Cupola Chase Way => Cupola Chase Way
# Initiative Way => Initiative Way
# Attmore Way => Attmore Way
# Zaldivar Way => Zaldivar Way
# Natalie Brook Way => Natalie Brook Way
# Trent Woods Way => Trent Woods Way
# Lower Shiloh Way => Lower Shiloh Way
# Bright Beginning Way => Bright Beginning Way
# Mt Pisgah Way => Mt Pisgah Way
# Boulderstone Way => Boulderstone Way
# Hill Hollow Way => Hill Hollow Way
# Partners Way => Partners Way
# Sorrell Brook Way => Sorrell Brook Way
# Thendara Way => Thendara Way
# Endeavor Way => Endeavor Way
# Winifred Way => Winifred Way
# Brook Fern Way => Brook Fern Way
# Talisman Way => Talisman Way
# Graywick Way => Graywick Way
# Chessridge Way => Chessridge Way
# Pond Glen Way => Pond Glen Way
# Bergeron Way => Bergeron Way
# Marlborough Way => Marlborough Way
# Holsten Bank Way => Holsten Bank Way
# Passaic Way => Passaic Way
# Wolf Village Way => Wolf Village Way
# Morrisville Square Way => Morrisville Square Way
# Lothian Way => Lothian Way
# Centre Green Way => Centre Green Way
# Leacroft Way => Leacroft Way
# Augustus Merrimon Way => Augustus Merrimon Way
# Environ Way => Environ Way
# Michaels Way => Michaels Way
# Calebra Way => Calebra Way
# Olde Weatherstone Way => Olde Weatherstone Way
# Glebe Way => Glebe Way
# Heck Andrews Way => Heck Andrews Way
# Plank Bridge Way => Plank Bridge Way
# Davis Dr. => Davis Drive
# Vilana Ridge => Vilana Ridge
# Glen Alpine Circle => Glen Alpine Circle
# Alliance Circle => Alliance Circle
# Shady Meadow Circle => Shady Meadow Circle
# Northwood Circle => Northwood Circle
# Parkleaf Circle => Parkleaf Circle
# Quarrystone Circle => Quarrystone Circle
# Phaeton Circle => Phaeton Circle
# Euphoria Circle => Euphoria Circle
# Page Point Circle => Page Point Circle
# Medallion Circle => Medallion Circle
# Hayloft Circle => Hayloft Circle
# Mount Rogers Circle => Mount Rogers Circle
# Ricky Circle => Ricky Circle
# Broyhill Circle => Broyhill Circle
# Penley Circle => Penley Circle
# Davie Circle => Davie Circle
# Noblewood Circle => Noblewood Circle
# Redbud Circle => Redbud Circle
# Cottonwood Circle => Cottonwood Circle
# Duck Pond Circle => Duck Pond Circle
# Croatan Circle => Croatan Circle
# Barriedale Circle => Barriedale Circle
# Talton Circle => Talton Circle
# Trillium Circle => Trillium Circle
# Parkvine Circle => Parkvine Circle
# Viewpoint Circle => Viewpoint Circle
# Arrow Leaf Circle => Arrow Leaf Circle
# Redwood Circle => Redwood Circle
# Meadowvale Circle => Meadowvale Circle
# Kevin Circle => Kevin Circle
# Lake Hollow Circle => Lake Hollow Circle
# Duke Medicine Circle => Duke Medicine Circle
# Meadowmont Village Circle => Meadowmont Village Circle
# Piper Stream Circle => Piper Stream Circle
# Langley Circle => Langley Circle
# Davis Grove Circle => Davis Grove Circle
# Pine Top Circle => Pine Top Circle
# Rockland Circle => Rockland Circle
# Tartan Circle => Tartan Circle
# Sunset Creek Circle => Sunset Creek Circle
# Parkmist Circle => Parkmist Circle
# Parkmount Circle => Parkmount Circle
# Golden Horseshoe Circle => Golden Horseshoe Circle
# Parkbrook Circle => Parkbrook Circle
# Ravens Point Circle => Ravens Point Circle
# Kintyre Circle => Kintyre Circle
# Davis Circle => Davis Circle
# Hillandale Rd. => Hillandale Road
# Chapel Hill Rd. => Chapel Hill Road
# Bayleaf Church Rd. => Bayleaf Church Road
# Highway 54 Bypass => Highway 54 Bypass
# US 15 501 Bypass => US 15 501 Bypass
# 27609-5360 => 27609-5360
# Dry Fork => Dry Fork
# US Highway 70 East => US Highway 70 East
# Deep Gap Run => Deep Gap Run
# Morgans Corner Run => Morgans Corner Run
# Triangle Family Practice => Triangle Family Practice
# Garrett Driver => Garrett Driver
# West Acres Crescent => West Acres Crescent
# Springerly Ln => Springerly Lane
# Bass Pro Ln => Bass Pro Lane
# Sunbow Falls Ln => Sunbow Falls Lane
# Balaji Pl => Balaji Pl
# Braddock Cir => Braddock Circle
# Daybrook Cir => Daybrook Circle
# East Chatham => East Chatham
# Crab Orchard Dr => Crab Orchard Drive
# Gold Star Dr => Gold Star Drive
# Grande Heights Dr => Grande Heights Drive
# Calabria Dr => Calabria Drive
# Stinson Dr => Stinson Drive
# University Dr => University Drive
# Westgate Dr => Westgate Drive
# Colonnade Center Dr => Colonnade Center Drive
# Kentington Dr => Kentington Drive
# Waterford Lake Dr => Waterford Lake Drive
# Triangle Plantation Dr => Triangle Plantation Drive
# Sablewood Dr => Sablewood Drive
# Carroll Hall => Carroll Hall
# US 15;US 501 => US 15;US 501
# NC 751 => NC 751
# NC Highway 751 => NC Highway 751
# Garner Rd Ste E => Garner Rd Ste E
# Weaver Dairy Road Extension => Weaver Dairy Road Extension
# Barrett Dr Suite 206 => Barrett Dr Suite 206
# Newton Grove => Newton Grove
# LaurelcherryStreet => LaurelcherryStreet
# Exchange Plaza => Exchange Plaza
# Park Forty Plaza => Park Forty Plaza
# City Hall Plaza => City Hall Plaza
# S Roxboro St => S Roxboro Street
# Main at North Hills St => Main at North Hills Street
# Holloway St => Holloway Street
# W Peace St => W Peace Street
# Kinsey St => Kinsey Street
# 9th St => 9th Street
# S Wilmington St => S Wilmington Street
# Hillsborough St => Hillsborough Street
# W Geer St => W Geer Street
# W Franklin St => W Franklin Street
# E Chatham St => E Chatham Street
# S Gregson St => S Gregson Street
# Autumn Hill Terrace #L6 => Autumn Hill Terrace #L6
# 27604-2428 => 27604-2428
# Pritchard Avenue Ext => Pritchard Avenue Ext
# New Hope Commons Boulevard Ext => New Hope Commons Boulevard Ext
# US 70 => US 70
# Page Rd #102 => Page Rd #102
# 100 => 100
# Westgate Park Dr #100 => Westgate Park Dr #100
# McCrimmon Pkwy => McCrimmon Parkway
# Skyland Ridge Pkwy => Skyland Ridge Parkway
# Farrow Glen Loop => Farrow Glen Loop
# Beckingham Loop => Beckingham Loop
# Amiable Loop => Amiable Loop
# N Fordham Blvd. => N Fordham Boulevard
# Southpoint Auto Park Blvd. => Southpoint Auto Park Boulevard
# Durham-Chapel Hill Blvd. => Durham-Chapel Hill Boulevard
# Brier Creek Pkwy #115 => Brier Creek Pkwy #115
# Alexander Promenade PI => Alexander Promenade PI
# US Highway 17 => US Highway 17
# Rocky Point => Rocky Point
# US 55 => US 55
# Highway 55 => Highway 55
# NC Highway 55 => NC Highway 55
# West Highway 54 => West Highway 54
# Highway 54 => Highway 54
# West State Highway 54 => West State Highway 54
# West NC Highway 54 => West NC Highway 54
# State Highway 54 => State Highway 54
# Brier Creek Pky => Brier Creek Parkway
# brier Creek Pky => brier Creek Parkway
# Yates Motor Company Alley => Yates Motor Company Alley
# W EDENTON ST => W EDENTON ST
# Wake Forest Highway => Wake Forest Highway
# NC 54 Highway => NC 54 Highway
# Apex Highway => Apex Highway
# Vernon Terrace => Vernon Terrace
# Stonebrook Terrace => Stonebrook Terrace
# Crestgate Terrace => Crestgate Terrace
# Fayetteville St #1100 => Fayetteville St #1100
# Capital Blvd => Capital Boulevard
# Fordham Blvd => Fordham Boulevard
# Airport Blvd => Airport Boulevard
# Lake Grove Blvd => Lake Grove Boulevard
# Southpoint Autopark Blvd => Southpoint Autopark Boulevard
# Martin Luther King Junior Blvd => Martin Luther King Junior Boulevard
# Witherspoon Blvd => Witherspoon Boulevard
# Martin Luther King Jr. Blvd => Martin Luther King Jr. Boulevard
# Martin Luther King Jr Blvd => Martin Luther King Jr Boulevard
# S Boylan Ave => S Boylan Avenue
# Glenwood Ave => Glenwood Avenue
# Atlantic Ave => Atlantic Avenue
# East Winmore Ave => East Winmore Avenue
# North Harrison Ave => North Harrison Avenue
# N Harrison Ave => N Harrison Avenue
# E. Winmore Ave => E. Winmore Avenue
# Mountford Ave => Mountford Avenue
# S. Boylan Ave => S. Boylan Avenue
# Meadowmont Village CIrcle => Meadowmont Village CIrcle
# Gulf Ct => Gulf Court
# Ashley Springs Ct => Ashley Springs Court
# Crawford Ct => Crawford Court
# Braidwood Ct => Braidwood Court
# Bevel Ct => Bevel Court
# Six Forks Road #1000 => Six Forks Road #1000

# %% [markdown]
# ## Audit Zip code
#
# Using part of the above codes let check zipcodes for uniformity or consitency. We can see from the result that the zipcode formatting is inconsistent. There are zipcodes which are not in the area that start with '26', some zipcodes have only 4 digits, the other zipcodes have formats like '27513-3507' and '275198404' which show inconsistency in the zipcode formatting.

# %%
# Let check zipcode for inconsistency 
from collections import defaultdict

def audit_zipcode(invalid_zipcodes, zipcode):
    twoDigits = zipcode[0:2]
    
    if not twoDigits.isdigit():
        invalid_zipcodes[twoDigits].add(zipcode)
    
    elif twoDigits != 27:
        invalid_zipcodes[twoDigits].add(zipcode)
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

zipcode_raleigh = audit_zip('raleigh_north-carolina.osm')
pprint.pprint(dict(zipcode_raleigh))
# Out:
# {'26': set(['2612-6401']),
#  '27': set(['27069-5439',
#             '27162-2750',
#             '27162-3449',
#             '27162-3452',
#             '27162-3454',
#             '27278',
#             '27502',
#             '27510',
#             '27511',
#             '27511-4701',
#             '27511-4702',
#             '27511-4734',
#             '27511-4735',
#             '27511-4762',
#             '27511-4791',
#             '27511-5525',
#             '27511-5927',
#             '27511-5928',
#             '27511-9998',
#             '27513',
#             '27513-3507',
#             '27513-3510',
#             '27513-3574',
#             '27513-3595',
#             '27513-3601',
#             '27513-3611',
#             '27513-4278',
#             '27513-8143',
#             '27513-8446',
#             '27513-8480',
#             '27513-8720',
#             '27514',
#             '27514-2885',
#             '27514-3307',
#             '27514-7415',
#             '27516',
#             '27517',
#             '27518',
#             '27519',
#             '27519-5685',
#             '27519-6205',
#             '27519-6206',
#             '27519-8400',
#             '27519-8403',
#             '27519-9443',
#             '275198404',
#             '275199',
#             '27523',
#             '27560',
#             '27560-7513',
#             '27560-8819',
#             '27560-9533',
#             '275609194',
#             '27599',
#             '27601',
#             '27601-1562',
#             '27601-1634',
#             '27602',
#             '27603',
#             '27603-1300',
#             '27603-1407',
#             '27603-1724',
#             '27603-1725',
#             '27604',
#             '27604-1502',
#             '27604-1512',
#             '27604-1513',
#             '27604-1514',
#             '27604-1515',
#             '27604-1516',
#             '27604-1517',
#             '27604-1518',
#             '27604-1519',
#             '27604-1520',
#             '27604-1521',
#             '27604-1522',
#             '27604-1523',
#             '27604-1524',
#             '27604-1525',
#             '27604-1526',
#             '27604-1601',
#             '27604-1602',
#             '27604-1603',
#             '27604-1605',
#             '27604-1606',
#             '27604-1607',
#             '27604-1608',
#             '27604-1609',
#             '27604-1610',
#             '27604-1611',
#             '27604-1612',
#             '27604-1613',
#             '27604-1614',
#             '27604-1615',
#             '27604-1616',
#             '27604-1621',
#             '27604-1623',
#             '27604-1624',
#             '27604-1632',
#             '27604-1645',
#             '27604-1646',
#             '27604-1647',
#             '27604-1648',
#             '27604-1649',
#             '27604-1650',
#             '27604-1651',
#             '27604-1652',
#             '27604-1653',
#             '27604-1654',
#             '27604-1656',
#             '27604-1659',
# Below is the output of the updated zipcode, some have 5 digits, other have 4 digits which needs updating.

# %%
# updating zipcode 

def update_name(zipcode):
    testNum = re.findall('[a-zA-Z]*', zipcode)
    if testNum:
        testNum = testNum[0]
    testNum.strip()
    if testNum == "CA":
        updatedzcode = (re.findall(r'\d+', zipcode))
        if updatedzcode:
            if updatedzcode.__len__() == 2:
                return (re.findall(r'\d+', zipcode))[0] + "-" +(re.findall(r'\d+', zipcode))[1]
            else:
                return (re.findall(r'\d+', zipcode))[0]

for street_type, ways in zipcode_raleigh.iteritems():
    for name in ways:
        better_name = update_name(name)
        print name, "=>", better_name
# Out:
# NC => None
# 2612-6401 => None
# 27609-5938 => None
# 27609-5939 => None
# 27612-2201 => None
# 27612-2200 => None
# 27609-5934 => None
# 27609-5935 => None
# 27609-5936 => None
# 27609-5937 => None
# 27609-5930 => None
# 27609-5931 => None
# 27609-5932 => None
# 27609-5933 => None
# 27609-5859 => None
# 27609-5853 => None
# 27609-5852 => None
# 27609-5850 => None
# 27609-5857 => None
# 27609-5856 => None
# 27609-4678 => None
# 27612-6302 => None
# 27604-2549 => None
# 27612-6304 => None
# 27612-6305 => None
# 27604-2543 => None
# 27604-2540 => None
# 27604-2547 => None
# 27604-2545 => None
# 27604-2544 => None
# 27604-2612 => None
# 27603-1725 => None
# 27603-1724 => None
# 27609-5589 => None
# 27609-5581 => None
# 27609-5580 => None
# 27609-5582 => None
# 27609-5619 => None
# 27609-5618 => None
# 27609-5615 => None
# 27609-5614 => None
# 27609-5617 => None
# 27609-5616 => None
# 27609-5611 => None
# 27609-5610 => None
# 27609-5613 => None
# 27609-5612 => None
# 27609-4528 => None
# 27609-4529 => None
# 27609-4524 => None
# 27609-4525 => None
# 27609-4526 => None
# 27609-4527 => None
# 27609-4520 => None
# 27609-4521 => None
# 27609-4522 => None
# 27609-4523 => None
# 27612-4821 => None
# 27612-4820 => None
# 27609-5101 => None
# 27609-5103 => None
# 27609-4329 => None
# 27609-5105 => None
# 27609-5104 => None
# 27609-5107 => None
# 27609-5106 => None
# 27612-2799 => None
# 27609-4451 => None
# 27609-4452 => None
# 27609-4321 => None
# 27609-4326 => None
# 27609-4327 => None
# 27609-4324 => None
# 27609-4325 => None
# 27609-5329 => None
# 27609-5328 => None
# 27612-3440 => None
# 27609-5321 => None
# 27609-5320 => None
# 27609-5323 => None
# 27609-5322 => None
# 27609-5325 => None
# 27609-5324 => None
# 27609-5327 => None
# 27609-5326 => None
# 27604-1624 => None
# 27604-1623 => None
# 27162-3449 => None
# 27604-1621 => None
# 27609-7306 => None
# 27513-3507 => None
# 27612-4007 => None
# 27612-4006 => None
# 27612-4005 => None
# 27612-4004 => None
# 27612-4009 => None
# 27612-4008 => None
# 27609-6030 => None
# 27609-6031 => None
# 27609-6032 => None
# 27609-6033 => None
# 27609-6034 => None
# 27609-6037 => None
# 27609-6038 => None
# 27609-6039 => None
# 27609-5354 => None
# 27617 => None
# 27616 => None
# 27615 => None
# 27614 => None
# 27613 => None
# 27612 => None
# 27610 => None
# 27609-6218 => None
# 27609-6215 => None
# 27609-6216 => None
# 27609-6217 => None
# 27609-6962 => None
# 27609-6960 => None
# 27609-6961 => None
# 27609-6969 => None
# 27612-6460 => None
# 27612-3936 => None
# 27609-7509 => None
# 27612-3932 => None
# 27612-3933 => None
# 27612-3930 => None
# 27612-3931 => None
# 27612-3939 => None
# 27609-6368 => None
# 27609-6367 => None
# 27609-6360 => None
# 27609-6361 => None
# 27607-5425 => None
# 27609-5923 => None
# 27609-5922 => None
# 27609-5921 => None
# 27609-5920 => None
# 27609-5927 => None
# 27609-5926 => None
# 27609-5925 => None
# 27609-5924 => None
# 27609-5929 => None
# 27609-5928 => None
# 27609-7161 => None
# 27609-7165 => None
# 27609-7164 => None
# 27604-2442 => None
# 27604-2443 => None
# 27604-2440 => None
# 27604-2441 => None
# 27604-2446 => None
# 27604-2447 => None
# 27604-2444 => None
# 27604-2445 => None
# 27604-2449 => None
# 27609-5828 => None
# 27609-5829 => None
# 27609-5826 => None
# 27609-5827 => None
# 27609-5824 => None
# 27609-5825 => None
# 27609-5822 => None
# 27609-5823 => None
# 27609-5820 => None
# 27609-5821 => None
# 27604-2422 => None
# 27612-6311 => None
# 27612-6317 => None
# 27604-3824 => None
# 27612-6319 => None
# 27609-7231 => None
# 27609-5620 => None
# 27609-5621 => None
# 27609-5622 => None
# 27609-5623 => None
# 27609-5624 => None
# 27609-5625 => None
# 27609-5626 => None
# 27609-5627 => None
# 27609-5628 => None
# 27609-5629 => None
# 27609-6322 => None
# 27609-4530 => None
# 27609-4537 => None
# 27604-2509 => None
# 27612-4814 => None
# 27609-5482 => None
# 27609-5483 => None
# 27612-3327 => None
# 27612-3326 => None
# 27612-3325 => None
# 27609-5134 => None
# 27609-5135 => None
# 27609-5136 => None
# 27609-5137 => None
# 27609-5131 => None
# 27609-5132 => None
# 27609-5133 => None
# 27609-4331 => None
# 27609-4330 => None
# 27609-4333 => None
# 27609-4444 => None
# 27609-4335 => None
# 27609-5139 => None
# 27609-4337 => None
# 27609-4440 => None
# 27612-3455 => None
# 27612-3454 => None
# 27612-3456 => None
# 27609-5318 => None
# 27612-3450 => None
# 27612-3453 => None
# 27612-3452 => None
# 27609-5314 => None
# 27609-5315 => None
# 27609-5316 => None
# 27609-5317 => None
# 27609-5310 => None
# 27609-5311 => None
# 27609-5313 => None
# 27162-3452 => None
# 27162-3454 => None
# 27511-5928 => None
# 27511-5927 => None
# 27609-5558 => None
# 27609-5559 => None
# 27609-5552 => None
# 27609-5553 => None
# 27609-5550 => None
# 27609-5551 => None
# 27609-5556 => None
# 27609-5557 => None
# 27609-5554 => None
# 27609-5555 => None
# 27612-2940 => None
# 27609-6027 => None
# 27609-6026 => None
# 27609-6025 => None
# 27609-6024 => None
# 27609-6023 => None
# 27609-6022 => None
# 27609-6021 => None
# 27609-6020 => None
# 27609-6029 => None
# 27609-6028 => None
# 275198404 => None
# 27609-4998 => None
# 27608 => None
# 27609 => None
# 27601 => None
# 27602 => None
# 27603 => None
# 27604 => None
# 27605 => None
# 27606 => None
# 27607 => None
# 27609-6759 => None
# 27609-6758 => None
# 27609-7372 => None
# 27609-6755 => None
# 27609-6754 => None
# 27609-6757 => None
# 27609-6756 => None
# 27609-6753 => None
# 27604-1502 => None
# 27609-6975 => None
# 27612-6452 => None
# 27609-6971 => None
# 27612-6453 => None
# 27612-6102 => None
# 27612-6103 => None
# 27612-6456 => None
# 27609-7082 => None
# 27609-7083 => None
# 27609-7081 => None
# 27612-3924 => None
# 27612-3927 => None
# 27612-6454 => None
# 27612-3922 => None
# 27612-6455 => None
# 27612-3929 => None
# 27612-6108 => None
# 27612-6118 => None
# 27612-3963 => None
# 27612-3962 => None
# 27605-1131 => None
# 27612-6522 => None
# 27612-5732 => None
# 27609-5954 => None
# 27609-5955 => None
# 27609-5952 => None
# 27609-5953 => None
# 27609-5950 => None
# 27609-5951 => None
# 27609-7798 => None
# 27609-5958 => None
# 27609-5959 => None
# 27609-7402 => None
# 27609-7403 => None
# 27609-7401 => None
# 27609-7406 => None
# 27609-7159 => None
# 27609-7404 => None
# 27609-7405 => None
# 27609-7154 => None
# 27609-7155 => None
# 27609-7156 => None
# 27609-7157 => None
# 27604-2451 => None
# 27604-2450 => None
# 27604-2452 => None
# 27604-2455 => None
# 27604-2454 => None
# 27604-2457 => None
# 27604-2456 => None
# 27604-2459 => None
# 27609-5831 => None
# 27609-5830 => None
# 27609-5832 => None
# 27608-2347 => None
# 27612-6327 => None
# 27612-6320 => None
# 27604-2528 => None
# 27604-2525 => None
# 27604-2524 => None
# 27604-2527 => None
# 27604-2526 => None
# 27604-2521 => None
# 27612-6329 => None
# 27604-2523 => None
# 27604-2522 => None
# 27604-2565 => None
# 27609-5637 => None
# 27609-5636 => None
# 27609-5635 => None
# 27609-5634 => None
# 27609-5633 => None
# 27612-5815 => None
# 27609-5631 => None
# 27609-5630 => None
# 27609-5639 => None
# 27609-5638 => None
# 27612-2621 => None
# 27612-2623 => None
# 27612-2625 => None
# 27604-2270 => None
# 27612-4806 => None
# 27612-4804 => None
# 27609-5122 => None
# 27609-5121 => None
# 27609-5120 => None
# 27609-5127 => None
# 27609-5126 => None
# 27609-5125 => None
# 27609-5124 => None
# 27609-5303 => None
# 27609-5302 => None
# 27609-5301 => None
# 27609-5307 => None
# 27609-5306 => None
# 27609-5305 => None
# 27609-5304 => None
# 27609-5309 => None
# 27609-5308 => None
# 27612-4247 => None
# 27609-4328 => None
# 27609-5549 => None
# 27609-5548 => None
# 27609-5102 => None
# 27609-5541 => None
# 27609-5540 => None
# 27609-5543 => None
# 27609-5542 => None
# 27609-5545 => None
# 27609-5544 => None
# 27609-5547 => None
# 27609-5546 => None
# 27612-2955 => None
# 27612-2954 => None
# 27612-2953 => None
# 27612-2952 => None
# 27612-2959 => None
# 27612-2958 => None
# 27609-4322 => None
# 27609-4323 => None
# 27609-4320 => None
# 27609-4453 => None
# 27609-4454 => None
# 27612-3468 => None
# 27609-4456 => None
# 27612-3461 => None
# 27612-3462 => None
# 27612-3463 => None
# 27612-3464 => None
# 27609-5910 => None
# 27612-3466 => None
# 27612-3467 => None
# 27609-6167 => None
# 27609-7751 => None
# 27612-3449 => None
# 27609-6760 => None
# 27609-6761 => None
# 27609-6762 => None
# 27609-6763 => None
# 27609-7055 => None
# 27604-1515 => None
# 27604-1514 => None
# 27604-1517 => None
# 27604-1516 => None
# 27604-1513 => None
# 27604-1512 => None
# 27604-1519 => None
# 27604-1518 => None
# 27701 => None
# 27612-3919 => None
# 27703 => None
# 27705 => None
# 27704 => None
# 27707 => None
# 27709 => None
# 27708 => None
# 27612-3912 => None
# 27612-3913 => None
# 27612-3914 => None
# 27612-6400 => None
# 27612-3916 => None
# 27612-3917 => None
# 27612-5444 => None
# 27612-5445 => None
# 27612-5446 => None
# 27612-5441 => None
# 27612-5442 => None
# 27612-5443 => None
# 27612-6246 => None
# 27612-6245 => None
# 27612-6244 => None
# 27609-5941 => None
# 27609-5940 => None
# 27612-6241 => None
# 27609-5942 => None
# 27609-5949 => None
# 27609-7411 => None
# 27609-7410 => None
# 27609-7141 => None
# 27609-7412 => None
# 27609-7415 => None
# 27609-7414 => None
# 27609-7417 => None
# 27609-7416 => None
# 27609-7419 => None
# 27609-7418 => None
# 27609-6410 => None
# 27609-6414 => None
# 27604-2465 => None
# 27604-2466 => None
# 27604-2460 => None
# 27604-2461 => None
# 27604-2462 => None
# 27609-7137 => None
# 27609-5800 => None
# 27612-6338 => None
# 27608-1844 => None
# 27612-6337 => None
# 27604-2511 => None
# 27609-7386 => None
# 27609-5705 => None
# 27612-3918 => None
# 27612-2610 => None
# 27612-2611 => None
# 27612-3910 => None
# 27612-3911 => None
# 27609-5158 => None
# 27609-5159 => None
# 27609-5156 => None
# 27612-6401 => None
# 27609-5154 => None
# 27609-5155 => None
# 27609-5152 => None
# 27609-5153 => None
# 27612-3915 => None
# 27609-4317 => None
# 27609-4315 => None
# 27609-4319 => None
# 27609-4318 => None
# 27609-5376 => None
# 27609-5374 => None
# 27609-5375 => None
# 27609-5371 => None
# 27609-6769 => None
# 27609-5379 => None
# 27612-2295 => None
# 27609-5578 => None
# 27609-5579 => None
# 27609-5574 => None
# 27609-5575 => None
# 27609-5576 => None
# 27612-2297 => None
# 27609-5570 => None
# 27609-5571 => None
# 27609-5207 => None
# 27609-5205 => None
# 27513-8143 => None
# 27612-4059 => None
# 27604-1520 => None
# 27604-1521 => None
# 27604-1522 => None
# 27604-1523 => None
# 27604-1524 => None
# 27604-1525 => None
# 27604-1526 => None
# 27612-6137 => None
# 27713 => None
# 27710 => None
# 27612-3907 => None
# 27612-3906 => None
# 27612-3905 => None
# 27612-3904 => None
# 27612-3903 => None
# 27612-3902 => None
# 27612-3901 => None
# 27609-7551 => None
# 27609-7553 => None
# 27609-7226 => None
# 27609-7227 => None
# 27609-7228 => None
# 27609-7229 => None
# 27609-6319 => None
# 27609-5978 => None
# 27609-5979 => None
# 27609-5970 => None
# 27609-5971 => None
# 27609-5972 => None
# 27609-5973 => None
# 27609-5974 => None
# 27609-5975 => None
# 27609-5976 => None
# 27609-5977 => None
# 27609-7136 => None
# 27609-6408 => None
# 27609-7426 => None
# 27609-7135 => None
# 27609-7132 => None
# 27609-7133 => None
# 27609-7130 => None
# 27609-7423 => None
# 27609-7428 => None
# 27609-6404 => None
# 27609-7138 => None
# 27609-6406 => None
# 27609-5944 => None
# 27609-5946 => None
# 27612-6243 => None
# 27609-5819 => None
# 27609-5818 => None
# 27609-5943 => None
# 27612-6348 => None
# 27612-6240 => None
# 27612-6340 => None
# 27604-2507 => None
# 27612-6126 => None
# 27609-7048 => None
# 27609-7049 => None
# 27604-2503 => None
# 27604-2502 => None
# 27604-2501 => None
# 27612-6127 => None
# 27609-7042 => None
# 27609-7043 => None
# 27612-6124 => None
# 27609-7044 => None
# 27604-2508 => None
# 27609-7023 => None
# 27609-7024 => None
# 27609-7025 => None
# 27609-7026 => None
# 27609-7142 => None
# 27609-7413 => None
# 27612-2603 => None
# 27612-2607 => None
# 27612-2606 => None
# 27612-2605 => None
# 27612-2609 => None
# 27612-2608 => None
# 27604-3309 => None
# 27604-3307 => None
# 27609-5149 => None
# 27609-5145 => None
# 27609-5144 => None
# 27609-5147 => None
# 27609-5146 => None
# 27609-5140 => None
# 27609-5143 => None
# 27609-4366 => None
# 27609-4364 => None
# 27609-4365 => None
# 27609-4363 => None
# 27609-5787 => None
# 27609-4368 => None
# 27609-5365 => None
# 27609-5364 => None
# 27609-5367 => None
# 27609-5366 => None
# 27609-5361 => None
# 27609-5360 => None
# 27609-5363 => None
# 27609-5362 => None
# 27609-5369 => None
# 27609-5563 => None
# 27609-5562 => None
# 27609-5561 => None
# 27609-5560 => None
# 27609-5567 => None
# 27609-5566 => None
# 27609-5565 => None
# 27609-5564 => None
# 27609-4561 => None
# 27609-5569 => None
# 27609-4563 => None
# 27609-4564 => None
# 27609-4565 => None
# 27609-5219 => None
# 27609-5218 => None
# 27609-5211 => None
# 27511-4791 => None
# 27609-5212 => None
# 27609-5215 => None
# 27609-5214 => None
# 27609-5217 => None
# 27609-5216 => None
# 27713-9714 => None
# 27604-8103 => None
# 27612-7203 => None
# 27516 => None
# 27609-7303 => None
# 27609-7302 => None
# 27609-4571 => None
# 27609-4570 => None
# 27609-6328 => None
# 27609-6329 => None
# 27609-6320 => None
# 27609-6321 => None
# 27513-4278 => None
# 27609-6323 => None
# 27609-6324 => None
# 27609-6325 => None
# 27609-6326 => None
# 27609-6327 => None
# 27609-2506 => None
# 27612-6519 => None
# 27609-5969 => None
# 27609-5968 => None
# 27609-5967 => None
# 27609-5966 => None
# 27609-5965 => None
# 27609-5964 => None
# 27609-5963 => None
# 27609-5962 => None
# 27609-5961 => None
# 27609-5960 => None
# 27609-7439 => None
# 27609-7438 => None
# 27519-6206 => None
# 27519-6205 => None
# 27609-7431 => None
# 27609-7437 => None
# 27609-7436 => None
# 27609-7125 => None
# 27609-7124 => None
# 27609-7127 => None
# 27609-7126 => None
# 27609-7121 => None
# 27609-7120 => None
# 27609-7123 => None
# 27609-7122 => None
# 27514-2885 => None
# 27609-7128 => None
# 27560-8819 => None
# 27609-6355 => None
# 27608-2319 => None
# 27612-6359 => None
# 27612-6358 => None
# 27612-6355 => None
# 27612-6354 => None
# 27612-6357 => None
# 27612-6356 => None
# 27612-6351 => None
# 27612-6350 => None
# 27612-6353 => None
# 27609-0011 => None
# 27609-7051 => None
# 27609-7050 => None
# 27612-6193 => None
# 27609-7056 => None
# 27603-1407 => None
# 27609-6356 => None
# 27604-2408 => None
# 27604-2409 => None
# 27604-2406 => None
# 27604-2407 => None
# 27604-2404 => None
# 27604-2405 => None
# 27604-2402 => None
# 27604-2403 => None
# 27604-2401 => None
# 27604-3311 => None
# 27609-5170 => None
# 27609-5171 => None
# 27609-5172 => None
# 27609-5174 => None
# 27609-4375 => None
# 27609-4376 => None
# 27609-4379 => None
# 27609-5900 => None
# 27612-2702 => None
# 27612-2703 => None
# 27612-2701 => None
# 27612-2707 => None
# 27612-2705 => None
# 27609-5350 => None
# 27609-5351 => None
# 27513-3574 => None
# 27609-5426 => None
# 27609-5516 => None
# 27609-5517 => None
# 27609-5515 => None
# 27609-5512 => None
# 27609-5513 => None
# 27609-5510 => None
# 27609-5511 => None
# 27609-4573 => None
# 27609-4572 => None
# 27609-5518 => None
# 27609-5519 => None
# 27609-5228 => None
# 27609-5229 => None
# 27609-5224 => None
# 27609-5225 => None
# 27609-5226 => None
# 27609-5227 => None
# 27609-5220 => None
# 27609-5221 => None
# 27609-5222 => None
# 27609-5223 => None
# 27609-5358 => None
# 27609-5428 => None
# 27609-5429 => None
# 27609-5422 => None
# 27609-5423 => None
# 27609-5420 => None
# 27609-5421 => None
# 27609-8106 => None
# 27609-5427 => None
# 27609-5424 => None
# 27609-5425 => None
# 27609-6155 => None
# 27612-2855 => None
# 27511-9998 => None
# 27608-1360 => None
# 27612-2751 => None
# 27609-4559 => None
# 27612-2758 => None
# 27519-8403 => None
# 27519-8400 => None
# 27609-7204 => None
# 27609-7205 => None
# 27609-7206 => None
# 27609-7207 => None
# 27609-7201 => None
# 27609-7202 => None
# 27609-7203 => None
# 27609-6337 => None
# 27609-6336 => None
# 27609-6335 => None
# 27609-6334 => None
# 27609-6333 => None
# 27609-6332 => None
# 27609-6331 => None
# 27609-6330 => None
# 27609-7840 => None
# 27612-6560 => None
# 27612-6561 => None
# 27609-7118 => None
# 27609-7119 => None
# 27609-7111 => None
# 27609-7112 => None
# 27609-7113 => None
# 27609-7114 => None
# 27609-7115 => None
# 27609-7116 => None
# 27609-7117 => None
# 27612-5721 => None
# 27612-5720 => None
# 27612-5723 => None
# 27612-5725 => None
# 27612-5724 => None
# 27612-5727 => None
# 27612-5726 => None
# 27612-5729 => None
# 27612-5728 => None
# 27612-5949 => None
# 27612-5948 => None
# 27612-5941 => None
# 27612-5940 => None
# 27612-5943 => None
# 27612-5947 => None
# 27612-5946 => None
# 27612-6122 => None
# 27612-6360 => None
# 27612-6361 => None
# 27612-6362 => None
# 27612-6363 => None
# 27612-6364 => None
# 27612-6365 => None
# 27612-6366 => None
# 27612-6367 => None
# 27612-6368 => None
# 27612-6369 => None
# 27609-5157 => None
# 27609-7064 => None
# 27609-7062 => None
# 27609-7063 => None
# 27612-6389 => None
# 27612-6382 => None
# 27612-6383 => None
# 27612-6381 => None
# 27612-6386 => None
# 27612-6387 => None
# 27612-6384 => None
# 27612-6385 => None
# 27608-2409 => None
# 27609-6831 => None
# 27604-2419 => None
# 27604-2418 => None
# 27604-2417 => None
# 27612-2798 => None
# 27604-2411 => None
# 27604-2410 => None
# 27604-2412 => None
# 27609-6345 => None
# 27612-6943 => None
# 27609-4348 => None
# 27609-4349 => None
# 27609-5165 => None
# 27609-5164 => None
# 27609-5163 => None
# 27609-5162 => None
# 27609-5161 => None
# 27609-5160 => None
# 27609-4340 => None
# 27609-4341 => None
# 27609-4342 => None
# 27609-4343 => None
# 27609-4344 => None
# 27609-4345 => None
# 27609-5169 => None
# 27609-5168 => None
# 27612-2718 => None
# 27612-2711 => None
# 27612-2713 => None
# 27612-2712 => None
# 27612-2715 => None
# 27612-2714 => None
# 27612-2717 => None
# 27612-2716 => None
# 27560-9533 => None
# 27513-8480 => None
# 27609-5505 => None
# 27609-5504 => None
# 27609-5507 => None
# 27609-5506 => None
# 27609-5501 => None
# 27609-5503 => None
# 27609-5502 => None
# 27612-6140 => None
# 27609-5509 => None
# 27609-5508 => None
# 27612-6141 => None
# 27609-5233 => None
# 27609-5232 => None
# 27609-5231 => None
# 27519-9443 => None
# 27609-5237 => None
# 27609-5236 => None
# 27609-5235 => None
# 27609-5234 => None
# 27609-5239 => None
# 27609-5238 => None
# 27518 => None
# 27609-6127 => None
# 27612-6321 => None
# 27609-5439 => None
# 27609-5438 => None
# 27609-5349 => None
# 27609-5431 => None
# 27609-5430 => None
# 27609-5433 => None
# 27609-5344 => None
# 27609-5435 => None
# 27609-5434 => None
# 27609-5437 => None
# 27609-5436 => None
# 27599 => None
# 27609-7327 => None
# 27609-7324 => None
# 27513-3601 => None
# 27609-7213 => None
# 276094507 => None
# 27609-6630 => None
# 27609-6637 => None
# 27609-7851 => None
# 27609-7853 => None
# 27609-7855 => None
# 27609-7854 => None
# 27609-5981 => None
# 27609-5980 => None
# 27609-5983 => None
# 27609-5982 => None
# 27609-5985 => None
# 27609-5984 => None
# 27609-7714 => None
# 27695 => None
# 27609-5577 => None
# 27609-7109 => None
# 27609-7108 => None
# 27609-7107 => None
# 27609-7106 => None
# 27609-7105 => None
# 27609-7104 => None
# 27609-7103 => None
# 27609-7102 => None
# 27609-7101 => None
# 27609-7100 => None
# 27612-5714 => None
# 27612-5715 => None
# 27612-5717 => None
# 27612-5710 => None
# 27612-5712 => None
# 27612-5713 => None
# 27612-5718 => None
# 27612-5719 => None
# 27612-6373 => None
# 27612-6372 => None
# 27612-6371 => None
# 27612-6370 => None
# 27609-7718 => None
# 27612-6398 => None
# 27612-6391 => None
# 27612-6390 => None
# 27604-2536 => None
# 27514-3307 => None
# 27609-6339 => None
# 27612-7156 => None
# 27609-6338 => None
# 27604-2420 => None
# 27278 => None
# 27612-6717 => None
# 27604-2423 => None
# 27604-2424 => None
# 27604-2425 => None
# 27604-2426 => None
# 27604-2427 => None
# 27604-2428 => None
# 27604-2429 => None
# 27609-7715 => None
# 27609-7208 => None
# 27609-4359 => None
# 27609-4357 => None
# 27609-4356 => None
# 27609-4355 => None
# 27609-4354 => None
# 27609-4353 => None
# 27609-4352 => None
# 27609-4351 => None
# 27609-4350 => None
# 27513-3595 => None
# 27609-5538 => None
# 27609-5539 => None
# 27609-5530 => None
# 27609-5531 => None
# 27609-5532 => None
# 27609-5533 => None
# 27609-5534 => None
# 27609-5535 => None
# 27609-5536 => None
# 27609-5537 => None
# 27513-8720 => None
# 27609-5247 => None
# 27609-5242 => None
# 27609-5243 => None
# 27609-5240 => None
# 27609-5241 => None
# 27609-5248 => None
# 27612-6147 => None
# 27609-7045 => None
# 27609-5405 => None
# 27560-7513 => None
# 27604-1652 => None
# 27604-1653 => None
# 27604-1650 => None
# 27604-1651 => None
# 27604-1656 => None
# 27604-1654 => None
# 27604-1659 => None
# 27513-3611 => None
# 27604-6058 => None
# 27613-3034 => None
# 27613-3033 => None
# 27612-6113 => None
# 27609-7262 => None
# 27612-6444 => None
# 27609-4910 => None
# 27612-6110 => None
# 27609-6849 => None
# 27609-6848 => None
# 27609-6845 => None
# 27609-6844 => None
# 27609-7441 => None
# 27609-7521 => None
# 27612-5709 => None
# 27612-5708 => None
# 27612-5703 => None
# 27612-5702 => None
# 27612-5701 => None
# 27612-5707 => None
# 27612-5706 => None
# 27612-5705 => None
# 27612-5704 => None
# 27609-7667 => None
# 27609-6342 => None
# 27609-7528 => None
# 27609-6340 => None
# 27603-1300 => None
# 27609-7006 => None
# 27609-7007 => None
# 27609-7004 => None
# 27609-7005 => None
# 27609-7002 => None
# 27609-7003 => None
# 27612-6142 => None
# 27609-7001 => None
# 27609-7838 => None
# 27612-6148 => None
# 27612-6149 => None
# 27609-7009 => None
# 27511-5525 => None
# 27604-2437 => None
# 27604-2436 => None
# 27604-2435 => None
# 27604-2434 => None
# 27604-2433 => None
# 27604-2432 => None
# 27604-2431 => None
# 27604-2430 => None
# 27609-7712 => None
# 27609-7713 => None
# 27609-7716 => None
# 27609-7717 => None
# 27604-2439 => None
# 27604-2438 => None
# 27612-3020 => None
# 27612-4813 => None
# 27609-4439 => None
# 27609-4432 => None
# 27609-4430 => None
# 27609-4435 => None
# 27609-4339 => None
# 27609-5529 => None
# 27609-5528 => None
# 27609-5527 => None
# 27609-5526 => None
# 27609-5525 => None
# 27609-5524 => None
# 27609-5523 => None
# 27609-5522 => None
# 27612-2640 => None
# 27609-4449 => None
# 27609-7427 => None
# 27513-8446 => None
# 27609-4332 => None
# 27609-5138 => None
# 27609-4334 => None
# 27609-5413 => None
# 27609-5901 => None
# 27609-5411 => None
# 27609-5417 => None
# 27609-5416 => None
# 27609-5415 => None
# 27609-5414 => None
# 27609-5419 => None
# 27609-5418 => None
# 27612-6201 => None
# 27514-7415 => None
# 27612-3451 => None
# 27609-5906 => None
# 27609-5319 => None
# 27604-1645 => None
# 27604-1647 => None
# 27604-1646 => None
# 27604-1649 => None
# 27604-1648 => None
# 27612-4081 => None
# 27609-6053 => None
# 27609-6050 => None
# 27609-6051 => None
# 27609-6056 => None
# 27609-6057 => None
# 27609-6054 => None
# 27609-6055 => None
# 27609-6058 => None
# 27609-6059 => None
# 27511-4735 => None
# 27511-4734 => None
# 27519-5685 => None
# 27609-4922 => None
# 27609-6475 => None
# 27613-3021 => None
# 27612-5916 => None
# 27612-5917 => None
# 27612-5914 => None
# 27612-5915 => None
# 27612-5912 => None
# 27612-5913 => None
# 27612-5910 => None
# 27612-5911 => None
# 27612-5918 => None
# 27612-5919 => None
# 27612-6159 => None
# 27612-6150 => None
# 27609-7015 => None
# 27609-7014 => None
# 27609-7017 => None
# 27609-7016 => None
# 27609-7011 => None
# 27609-7010 => None
# 27609-7013 => None
# 27609-7012 => None
# 27609-7019 => None
# 27609-7018 => None
# 27609-8136 => None
# 27609-8138 => None
# 275609194 => None
# 27612-6063 => None
# 27612-6062 => None
# 27612-6027 => None
# 27612-6025 => None
# 27612-6028 => None
# 27612-2746 => None
# 27612-2747 => None
# 27612-2745 => None
# 27609-4421 => None
# 27609-4420 => None
# 27609-4423 => None
# 27609-4422 => None
# 27609-4425 => None
# 27609-4424 => None
# 27612-2748 => None
# 27609-4426 => None
# 276095352 => None
# 27609-5643 => None
# 27609-5640 => None
# 27609-5646 => None
# 27609-5647 => None
# 27609-5644 => None
# 27609-5645 => None
# 27609-5648 => None
# 27609-5649 => None
# 27609-5467 => None
# 27609-5465 => None
# 27609-5460 => None
# 27609-5461 => None
# 27609-6958 => None
# 27895 => None
# 27612-4346 => None
# 27604-1675 => None
# 27612-4082 => None
# 27609-5262 => None
# 27609-5264 => None
# 27609-5265 => None
# 27612-2922 => None
# 27612-2923 => None
# 27612-2920 => None
# 27612-2921 => None
# 27612-2926 => None
# 27612-2924 => None
# 27612-2925 => None
# 27609-6041 => None
# 27609-6040 => None
# 27609-6043 => None
# 27609-6042 => None
# 27609-6045 => None
# 27609-6044 => None
# 27609-6047 => None
# 27609-6046 => None
# 27609-6049 => None
# 27609-6048 => None
# 27511-4701 => None
# 27511-4702 => None
# 27609-5167 => None
# 27609-5166 => None
# 27609-7240 => None
# 27609-7241 => None
# 27609-7248 => None
# 27609-7249 => None
# 27523 => None
# 27609-6862 => None
# 27609-6864 => None
# 27609-4346 => None
# 27609-4347 => None
# 27609-6261 => None
# 27612-5901 => None
# 27612-5908 => None
# 27609-7028 => None
# 27609-7029 => None
# 27612-6129 => None
# 27609-7020 => None
# 27609-7021 => None
# 27609-7022 => None
# 27612-6125 => None
# 27601-1562 => None
# 27612-6123 => None
# 27612-6120 => None
# 27609-7027 => None
# 27609-7037 => None
# 27609-7809 => None
# 27609-7806 => None
# 27609-7807 => None
# 27609-7804 => None
# 27609-7802 => None
# 27609-7803 => None
# 27609-7801 => None
# 27609-7034 => None
# 27609-7030 => None
# 27609-7424 => None
# 27609-7425 => None
# 27609-7134 => None
# 27612-6233 => None
# 27612-6230 => None
# 27612-6231 => None
# 27612-6236 => None
# 27612-6237 => None
# 27612-6234 => None
# 27612-6235 => None
# 27609-7420 => None
# 27612-6238 => None
# 27612-6239 => None
# 27609-7730 => None
# 27609-7421 => None
# 27609-6959 => None
# 27609-7131 => None
# 27609-5728 => None
# 27609-6405 => None
# 27609-5727 => None
# 27609-5721 => None
# 27609-7429 => None
# 27609-6407 => None
# 27609-4418 => None
# 27612-2750 => None
# 27612-2752 => None
# 27609-4414 => None
# 27609-4410 => None
# 27609-4411 => None
# 27609-4413 => None
# 27609-5097 => None
# 27609-5096 => None
# 27609-5095 => None
# 27609-5092 => None
# 27609-5091 => None
# 27609-5099 => None
# 27609-5098 => None
# 27609-5651 => None
# 27609-5650 => None
# 27609-5653 => None
# 27609-5652 => None
# 27609-5655 => None
# 27609-5654 => None
# 27609-5657 => None
# 27609-5656 => None
# 27609-5659 => None
# 27609-5658 => None
# 27609-5471 => None
# 27609-5470 => None
# 27609-5472 => None
# 27612-3404 => None
# 27609-1601 => None
# 27612-2939 => None
# 27612-3431 => None
# 27609-5339 => None
# 27612-5939 => None
# 27604-2504 => None
# 27612-3439 => None
# 27609-6819 => None
# 27612-6229 => None
# 27612-5932 => None
# 27612-5933 => None
# 27609-6701 => None
# 27612-0877 => None
# 27609-6257 => None
# 27609-6251 => None
# 27609-6252 => None
# 27609-7409 => None
# 27609- => None
# 27612-6139 => None
# 27612-6138 => None
# 27612-6135 => None
# 27612-6134 => None
# 27609-7035 => None
# 27612-6136 => None
# 27609-7033 => None
# 27612-6133 => None
# 27612-6132 => None
# 27609-7819 => None
# 27609-7818 => None
# 27609-7815 => None
# 27609-7814 => None
# 27609-7817 => None
# 27609-7810 => None
# 27609-7813 => None
# 27609-7812 => None
# 27612-5938 => None
# 27609-7722 => None
# 27609-7727 => None
# 27612-6224 => None
# 27612-6227 => None
# 27612-6226 => None
# 27612-5930 => None
# 27612-6228 => None
# 27609-7729 => None
# 27609-7728 => None
# 27612-5934 => None
# 27612-5935 => None
# 27612-5937 => None
# 27609-4391 => None
# 27609-5862 => None
# 27609-5863 => None
# 27609-5860 => None
# 27609-5861 => None
# 27609-5867 => None
# 27612-6046 => None
# 27612-6457 => None
# 27609-4403 => None
# 27609-4402 => None
# 27609-4401 => None
# 27609-4407 => None
# 27609-4406 => None
# 27609-4405 => None
# 27609-4404 => None
# 27609-4409 => None
# 27609-4408 => None
# 27609-5346 => None
# 27609-5345 => None
# 27609-5432 => None
# 27609-5343 => None
# 27609-5342 => None
# 27609-5666 => None
# 27609-5667 => None
# 27609-5660 => None
# 27609-5661 => None
# 27609-5662 => None
# 27609-5663 => None
# 27609-5340 => None
# 27609-5668 => None
# 27609-5449 => None
# 27609-5440 => None
# 27609-5441 => None
# 27609-5442 => None
# 27609-5443 => None
# 27609-5444 => None
# 27609-5446 => None
# 27609-5447 => None
# 27612-2762 => None
# 27612-3417 => None
# 27604-1616 => None
# 27604-1614 => None
# 27604-1615 => None
# 27604-1612 => None
# 27604-1613 => None
# 27604-1610 => None
# 27604-1611 => None
# 27609-5287 => None
# 27609-6068 => None
# 27609-6063 => None
# 27609-6062 => None
# 27609-6061 => None
# 27609-6060 => None
# 27609-6067 => None
# 27609-6066 => None
# 27609-6065 => None
# 27609-6064 => None
# 27511-4762 => None
# 27604-1725 => None
# 27502 => None
# 27609-6245 => None
# 27609-6244 => None
# 27162-2750 => None
# 27612-6100 => None
# 27612-3968 => None
# 27612-6450 => None
# 27612-6451 => None
# 27612-6104 => None
# 27612-6105 => None
# 27612-6106 => None
# 27612-6107 => None
# 27612-3961 => None
# 27612-6458 => None
# 27612-6459 => None
# 27612-3964 => None
# 27612-3967 => None
# 27609-7820 => None
# 27609-7823 => None
# 27609-7824 => None
# 27609-7825 => None
# 27609-7826 => None
# 27604-2563 => None
# 27612-5817 => None
# 27612-5816 => None
# 27604-2567 => None
# 27612-5814 => None
# 27612-5819 => None
# 27612-5818 => None
# 27609-4494 => None
# 27609-5918 => None
# 27609-5919 => None
# 27609-5912 => None
# 27609-5913 => None
# 27612-2227 => None
# 27609-5916 => None
# 27609-5917 => None
# 27609-5914 => None
# 27609-5915 => None
# 27612-6214 => None
# 27612-6215 => None
# 27612-6216 => None
# 27612-6217 => None
# 27612-6210 => None
# 27612-6213 => None
# 27612-5927 => None
# 27612-6218 => None
# 27612-6219 => None
# 27609-5956 => None
# 27609-5957 => None
# 27609-5707 => None
# 27609-5706 => None
# 27609-5873 => None
# 27609-5704 => None
# 27609-5703 => None
# 27609-5702 => None
# 27609-5701 => None
# 27609-4443 => None
# 27609-5671 => None
# 27609-5670 => None
# 27609-7879 => None
# 27609-5108 => None
# 27609-7407 => None
# 27609-4508 => None
# 27609-4509 => None
# 27609-4442 => None
# 27609-4502 => None
# 27609-4503 => None
# 27609-4501 => None
# 27609-4507 => None
# 27609-4504 => None
# 27609-4505 => None
# 27609-7408 => None
# 27609-4441 => None
# 27609-5459 => None
# 27609-5458 => None
# 27609-5457 => None
# 27609-5456 => None
# 27609-5453 => None
# 27609-5452 => None
# 27609-5451 => None
# 27609-5450 => None
# 27612-3429 => None
# 27612-3424 => None
# 27612-3425 => None
# 27612-3426 => None
# 27612-3420 => None
# 27612-3421 => None
# 27612-3422 => None
# 27612-3423 => None
# 27604-1609 => None
# 27604-1608 => None
# 27604-1605 => None
# 27604-1607 => None
# 27604-1606 => None
# 27604-1601 => None
# 27604-1603 => None
# 27604-1602 => None
# 27612-2919 => None
# 27609-6018 => None
# 27609-6019 => None
# 27609-6016 => None
# 27609-6017 => None
# 27609-6015 => None
# 27609-6013 => None
# 27609-6011 => None
# 27601-1634 => None
# 27612-3920 => None
# 27609-6126 => None
# 27519 => None
# 27514 => None
# 27609-6128 => None
# 27517 => None
# 27510 => None
# 27511 => None
# 27513 => None
# 27609-4562 => None
# 27609-5568 => None
# 27609-7631 => None
# 27609-6237 => None
# 27609-6728 => None
# 27609-6729 => None
# 27609-6238 => None
# 27609-7036 => None
# 27612-6117 => None
# 27612-6116 => None
# 27612-6443 => None
# 27612-6114 => None
# 27612-6445 => None
# 27612-6112 => None
# 27612-6111 => None
# 27612-6446 => None
# 27612-3954 => None
# 27612-6448 => None
# 27612-3951 => None
# 27612-6119 => None
# 27612-3953 => None
# 27609-6838 => None
# 27609-6839 => None
# 27609-6348 => None
# 27609-7522 => None
# 27609-7831 => None
# 27609-6830 => None
# 27609-6343 => None
# 27609-6832 => None
# 27609-6341 => None
# 27609-6346 => None
# 27609-6347 => None
# 27609-6344 => None
# 27609-6837 => None
# 27604-2554 => None
# 27604-2550 => None
# 27604-2551 => None
# 27604-2552 => None
# 27604-2553 => None
# 27609-5909 => None
# 27609-5908 => None
# 27612-6203 => None
# 27612-6202 => None
# 27609-5903 => None
# 27609-5902 => None
# 27609-5905 => None
# 27609-5904 => None
# 27609-5907 => None
# 27612-6204 => None
# 27609-7747 => None
# 27609-7746 => None
# 27609-7741 => None
# 27609-4450 => None
# 27609-5844 => None
# 27609-5845 => None
# 27609-5846 => None
# 27609-5847 => None
# 27609-5840 => None
# 27609-5841 => None
# 27609-5842 => None
# 27609-5843 => None
# 27612-6067 => None
# 27612-6066 => None
# 27612-6065 => None
# 27612-6064 => None
# 27609-5848 => None
# 27609-5849 => None
# 27612-6060 => None
# 27609-4461 => None
# 27609-4460 => None
# 27612-3800 => None
# 27609-5608 => None
# 27609-5609 => None
# 27609-5606 => None
# 27609-5607 => None
# 27609-5604 => None
# 27609-5605 => None
# 27609-5602 => None
# 27609-5603 => None
# 27609-5601 => None
# 27069-5439 => None
# 27609-4519 => None
# 27609-4518 => None
# 27609-4511 => None
# 27609-4510 => None
# 27609-4513 => None
# 27609-4512 => None
# 27609-4515 => None
# 27609-4514 => None
# 27609-4517 => None
# 27609-4516 => None
# 27609-5112 => None
# 27609-5113 => None
# 27609-5116 => None
# 27609-5117 => None
# 27609-5114 => None
# 27609-5115 => None
# 27609-5118 => None
# 27609-5119 => None
# 27612-3432 => None
# 27609-5338 => None
# 27612-3430 => None
# 27612-3437 => None
# 27612-3436 => None
# 27612-3435 => None
# 27612-3434 => None
# 27609-5332 => None
# 27609-5333 => None
# 27609-5330 => None
# 27609-5331 => None
# 27609-5336 => None
# 27609-5337 => None
# 27609-5334 => None
# 27609-5335 => None
# 27604-1632 => None
# 27609-5632 => None
# 27513-3510 => None
# 27609-5213 => None
# 27612-2966 => None
# 27612-2967 => None
# 27612-4010 => None
# 27612-2960 => None
# 27612-2961 => None
# 27609-6009 => None
# 27609-6008 => None
# 27609-6005 => None
# 27609-6004 => None
# 27609-6007 => None
# 27609-6006 => None
# 27609-6001 => None
# 27609-6000 => None
# 27609-6003 => None
# 27609-6002 => None
# 27609-5341 => None
# 275199 => None
# 27560 => None
# 27609-4429 => None
# 27609-4428 => None
# 27609-6739 => None
# 27610-2636 => None
# 27609-7513 => None
# 27612-2749 => None
# 27609-6353 => None
# 27612-3943 => None
# 27612-3942 => None
# 27609-6824 => None
# 27612-3947 => None
# 27609-7518 => None
# 27612-3949 => None
# 27612-3948 => None
# 27609-6822 => None
# 27609-6359 => None
# 27609-6358 => None
# 27609-6357 => None
# 27609-6828 => None
# 27609-6351 => None
# 27609-6350 => None
# 27609-6825 => None
# 27609-6352 => None
# 27609-6823 => None
# 27609-6354 => None
# 27609-6821 => None
# 27609-6820 => None
# 28616 => None

# %% [markdown]
# # Preparing for DataBase-MongoDB
# To store the data into a mongodb database, it could be converted from XML to JSON format. We need to do the following to convert the data from XML format to JSON.
#
# - you should process only 2 types of top level tags: "node" and "way"
# - all attributes of "node" and "way" should be turned into regular key/value pairs, except:
#     - attributes in the CREATED array should be added under a key "created"
#     - attributes for latitude and longitude should be added to a "pos" array,
#       for use in geospacial indexing. Make sure the values inside "pos" array are floats
#       and not strings.
# - if the second level tag "k" value contains problematic characters, it should be ignored
# - if the second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
# - if the second level tag "k" value does not start with "addr:", but contains ":", you can
#   process it in a way that you feel is best. For example, you might split it into a two-level
#   dictionary like with "addr:", or otherwise convert the ":" to create a valid key.
# - if there is a second ":" that separates the type/direction of a street,
#   the tag should be ignored, for example:

# %%
import re
import codecs
import json

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
address_regex = re.compile(r'^addr\:')
street_regex = re.compile(r'^street')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        node['type'] = element.tag
        # let us assign an empty dict to address
        address = {}
        # parse through attributes of all elements
        for attr  in element.attrib:
            if attr in CREATED:
                if 'created' not in node:
                    node['created'] = {}
                node['created'][attr] = element.get(attr)
            elif attr in ['lat', 'lon']:
                continue
            else:
                node[attr] = element.get(attr)
        # finding lattitute and logitude positions
        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.get('lat')), float(element.get('lon'))]

        # parse second-level tags for nodes
        for e in element:
            # parse second-level tags for ways and populate `node_refs`
            if e.tag == 'nd':
                if 'node_refs' not in node:
                    node['node_refs'] = []
                if 'ref' in e.attrib:
                    node['node_refs'].append(e.get('ref'))

            # throw out not-tag elements and elements without `k` or `v`
            if e.tag != 'tag' or 'k' not in e.attrib or 'v' not in e.attrib:
                continue
            key = e.get('k')
            val = e.get('v')

            # skip problematic characters
            if problemchars.search(key):
                continue

            # parse address k-v pairs
            elif address_regex.search(key):
                key = key.replace('addr:', '')
                address[key] = val

            # catch-all
            else:
                node[key] = val
        # compile address
        if len(address) > 0:
            node['address'] = {}
            street_full = None
            street_dict = {}
            street_format = ['prefix', 'name', 'type']
            # parse through address objects
            for key in address:
                val = address[key]
                if street_regex.search(key):
                    if key == 'street':
                        street_full = val
                    elif 'street:' in key:
                        street_dict[key.replace('street:', '')] = val
                else:
                    node['address'][key] = val
            # assign street_full or fallback to compile street dict
            if street_full:
                node['address']['street'] = street_full
            elif len(street_dict) > 0:
                node['address']['street'] = ' '.join([street_dict[key] for key in street_format])
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %%
# Print the JSON data type
process_map('raleigh_north-carolina.osm',False)
# Out:
# [{'created': {'changeset': '7525913',
#    'timestamp': '2011-03-11T18:03:13Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '4'},
#   'id': '21592692',
#   'pos': [35.9746754, -78.9086172],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:46Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595910',
#   'pos': [35.9323309, -78.9249163],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:34Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21595911',
#   'pos': [35.9293805, -78.9272018],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:34Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21595918',
#   'pos': [35.9291511, -78.9249346],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:34Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21595919',
#   'pos': [35.9294047, -78.9252983],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:58Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595920',
#   'pos': [35.9289895, -78.9269356],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:34Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21595921',
#   'pos': [35.9292973, -78.9258812],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:43Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595922',
#   'pos': [35.9285729, -78.9286658],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:59Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595923',
#   'pos': [35.9288788, -78.9299995],
#   'type': 'node'},
#  {'created': {'changeset': '21023776',
#    'timestamp': '2014-03-10T12:14:09Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595924',
#   'pos': [35.9291183, -78.9310836],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:47Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595925',
#   'pos': [35.9287671, -78.9313233],
#   'type': 'node'},
#  {'created': {'changeset': '21023776',
#    'timestamp': '2014-03-10T12:14:09Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595926',
#   'pos': [35.9280179, -78.9299797],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:54Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595927',
#   'pos': [35.9275885, -78.9284131],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:35Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21595928',
#   'pos': [35.9253088, -78.9276284],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:35Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21595929',
#   'pos': [35.9247503, -78.9284339],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:35Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '4'},
#   'id': '21595930',
#   'pos': [35.9240974, -78.9286302],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:35Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '4'},
#   'id': '21595931',
#   'pos': [35.9232993, -78.9271646],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T19:00:34Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21595932',
#   'name': 'Woodcroft Walking Trails',
#   'pos': [35.923532, -78.9299038],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:41Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '2'},
#   'id': '21595933',
#   'pos': [35.9227902, -78.9311111],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:48Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '2'},
#   'id': '21595934',
#   'pos': [35.9221702, -78.9316473],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:49Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '2'},
#   'id': '21595935',
#   'name': 'Woodcroft Walking Trails',
#   'pos': [35.9214943, -78.9308262],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:41Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '3'},
#   'id': '21595936',
#   'pos': [35.9218034, -78.9320361],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:41Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '3'},
#   'id': '21595937',
#   'pos': [35.9214342, -78.9325779],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:38Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '4'},
#   'id': '21595938',
#   'pos': [35.9212372, -78.9334002],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:38Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595942',
#   'pos': [35.9214368, -78.933335],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:38Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '4'},
#   'id': '21595943',
#   'name': 'Woodcroft Walking Trails',
#   'pos': [35.9217103, -78.9325557],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:41Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '2'},
#   'id': '21595944',
#   'pos': [35.9228684, -78.9330605],
#   'type': 'node'},
#  {'created': {'changeset': '21023776',
#    'timestamp': '2014-03-10T12:14:09Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '4'},
#   'id': '21595945',
#   'pos': [35.9244363, -78.9330776],
#   'type': 'node'},
#  {'created': {'changeset': '21023776',
#    'timestamp': '2014-03-10T12:14:09Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '4'},
#   'id': '21595946',
#   'pos': [35.9262621, -78.9322367],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595947',
#   'pos': [35.9260971, -78.9328594],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595948',
#   'pos': [35.9261529, -78.9329921],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595949',
#   'pos': [35.9263541, -78.9342454],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:46Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '2'},
#   'id': '21595950',
#   'pos': [35.9243096, -78.9345296],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595951',
#   'pos': [35.925248, -78.9342322],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:48Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '2'},
#   'id': '21595952',
#   'pos': [35.9242984, -78.934753],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:54Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595953',
#   'pos': [35.9255859, -78.9389134],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595954',
#   'pos': [35.9266692, -78.9395514],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595955',
#   'pos': [35.9274769, -78.9381063],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595956',
#   'pos': [35.9276523, -78.9370707],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:46Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595957',
#   'pos': [35.9275438, -78.9361495],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:55Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595958',
#   'pos': [35.927002, -78.935077],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:52Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595959',
#   'pos': [35.9264657, -78.9345352],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:59Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595960',
#   'pos': [35.9262367, -78.9344235],
#   'type': 'node'},
#  {'created': {'changeset': '27076730',
#    'timestamp': '2014-11-27T20:18:57Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595961',
#   'pos': [35.9263593, -78.9415072],
#   'type': 'node'},
#  {'created': {'changeset': '2109994',
#    'timestamp': '2009-08-11T17:36:13Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595962',
#   'pos': [35.9257563, -78.942132],
#   'type': 'node'},
#  {'created': {'changeset': '27076730',
#    'timestamp': '2014-11-27T20:18:57Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595963',
#   'pos': [35.9244039, -78.9417233],
#   'type': 'node'},
#  {'created': {'changeset': '2109994',
#    'timestamp': '2009-08-11T17:35:50Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595964',
#   'pos': [35.923913, -78.9418471],
#   'type': 'node'},
#  {'created': {'changeset': '2109994',
#    'timestamp': '2009-08-11T17:35:08Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '4'},
#   'id': '21595965',
#   'pos': [35.9234412, -78.9409276],
#   'type': 'node'},
#  {'created': {'changeset': '26142549',
#    'timestamp': '2014-10-17T11:48:58Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '6'},
#   'id': '21595966',
#   'pos': [35.9232348, -78.9410859],
#   'type': 'node'},
#  {'created': {'changeset': '2109994',
#    'timestamp': '2009-08-11T17:35:30Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595967',
#   'pos': [35.9231533, -78.9413946],
#   'type': 'node'},
#  {'created': {'changeset': '26142549',
#    'timestamp': '2014-10-17T11:48:58Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595968',
#   'pos': [35.9199207, -78.9440985],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:49Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595969',
#   'pos': [35.9194331, -78.9444054],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595970',
#   'pos': [35.9192261, -78.9444565],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:54Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595971',
#   'pos': [35.919099, -78.9426086],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595972',
#   'pos': [35.9189298, -78.9414564],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595973',
#   'pos': [35.9188308, -78.9394684],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595974',
#   'pos': [35.9190187, -78.9389433],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:46Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595975',
#   'pos': [35.9200643, -78.9369818],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595976',
#   'pos': [35.9204322, -78.9361566],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:41Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '3'},
#   'id': '21595977',
#   'pos': [35.9213082, -78.9343482],
#   'type': 'node'},
#  {'created': {'changeset': '4698502',
#    'timestamp': '2010-05-14T17:56:48Z',
#    'uid': '13832',
#    'user': 'Peter14',
#    'version': '3'},
#   'id': '21595978',
#   'pos': [35.9213124, -78.9344764],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T18:44:44Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '4'},
#   'id': '21595979',
#   'pos': [35.9220622, -78.9364128],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:49Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595980',
#   'pos': [35.9193298, -78.9467853],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:45Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595981',
#   'pos': [35.919303, -78.9473928],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:54Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595982',
#   'pos': [35.9196901, -78.94812],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595983',
#   'pos': [35.9198968, -78.9486961],
#   'type': 'node'},
#  {'created': {'changeset': '15766289',
#    'timestamp': '2013-04-17T19:30:28Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595984',
#   'pos': [35.9196547, -78.9498941],
#   'type': 'node'},
#  {'created': {'changeset': '15766289',
#    'timestamp': '2013-04-17T19:30:28Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595985',
#   'pos': [35.9199776, -78.9507614],
#   'type': 'node'},
#  {'created': {'changeset': '15766289',
#    'timestamp': '2013-04-17T19:30:28Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21595986',
#   'pos': [35.9202835, -78.9505843],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:45Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595987',
#   'pos': [35.921139, -78.9504602],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:55Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595988',
#   'pos': [35.9217094, -78.9502768],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595989',
#   'pos': [35.9217303, -78.9504051],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:59Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595990',
#   'pos': [35.9219077, -78.9503996],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:57Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595991',
#   'pos': [35.9218494, -78.948871],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595992',
#   'pos': [35.9215929, -78.9487777],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:39Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595993',
#   'pos': [35.9219294, -78.9479262],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595994',
#   'pos': [35.9217526, -78.9477504],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595995',
#   'pos': [35.9222158, -78.9467897],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21595996',
#   'pos': [35.9231112, -78.945592],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:56Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21595997',
#   'pos': [35.9225186, -78.9467982],
#   'type': 'node'},
#  {'created': {'changeset': '24719051',
#    'timestamp': '2014-08-13T09:30:28Z',
#    'uid': '87586',
#    'user': 'ToddDTaft',
#    'version': '3'},
#   'id': '21595998',
#   'pos': [35.9233207, -78.9457309],
#   'type': 'node'},
#  {'created': {'changeset': '24719051',
#    'timestamp': '2014-08-13T09:30:28Z',
#    'uid': '87586',
#    'user': 'ToddDTaft',
#    'version': '3'},
#   'id': '21595999',
#   'pos': [35.9238053, -78.9445859],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21596000',
#   'pos': [35.9235864, -78.9443188],
#   'type': 'node'},
#  {'created': {'changeset': '24719051',
#    'timestamp': '2014-08-13T09:30:28Z',
#    'uid': '87586',
#    'user': 'ToddDTaft',
#    'version': '5'},
#   'highway': 'crossing',
#   'id': '21596001',
#   'pos': [35.9235432, -78.942094],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:56Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21596002',
#   'pos': [35.9223266, -78.9521809],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21596003',
#   'pos': [35.9225765, -78.9526456],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:36:00Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21596004',
#   'pos': [35.9225695, -78.9532649],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:58Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21596005',
#   'pos': [35.9222853, -78.954363],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:49Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21596006',
#   'pos': [35.9222803, -78.9547471],
#   'type': 'node'},
#  {'created': {'changeset': '15265310',
#    'timestamp': '2013-03-06T00:56:53Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '21596007',
#   'pos': [35.9232859, -78.9451947],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:54Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21596008',
#   'pos': [35.9241364, -78.9432324],
#   'type': 'node'},
#  {'created': {'changeset': '9059469',
#    'timestamp': '2011-08-18T18:44:44Z',
#    'uid': '398883',
#    'user': 'FIM',
#    'version': '3'},
#   'id': '21596009',
#   'pos': [35.9231522, -78.9353887],
#   'type': 'node'},
#  {'created': {'changeset': '6118030',
#    'timestamp': '2010-10-20T17:35:39Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '2'},
#   'id': '21596013',
#   'pos': [35.928502, -78.9277815],
#   'type': 'node'},
#  {'created': {'changeset': '15773218',
#    'timestamp': '2013-04-18T13:01:39Z',
#    'uid': '630082',
#    'user': 'DZanter',
#    'version': '3'},
#   'id': '21596014',
#   'pos': [35.9269056, -78.9392795],
#   'type': 'node'},
#  {'created': {'changeset': '24719051',
#    'timestamp': '2014-08-13T09:30:29Z',
#    'uid': '87586',
#    'user': 'ToddDTaft',
#    'version': '3'},
#   'id': '21596015',
#   'pos': [35.9239559, -78.9420653],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:11Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '172',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002547',
#   'id': '157548550',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'University Acres',
#   'place': 'hamlet',
#   'pos': [36.0148638, -79.0472333],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:15Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '75',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002575',
#   'id': '157553001',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Ridgefield Park',
#   'place': 'hamlet',
#   'pos': [35.9215333, -79.0177881],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:16Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '71',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Chatham',
#   'gnis:County_num': '037',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '985012',
#   'id': '157554919',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Chatham,North Carolina,N.C.,NC,USA',
#   'name': 'Farrington',
#   'place': 'hamlet',
#   'pos': [35.8018148, -79.013899],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:19Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '215',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002504',
#   'id': '157557688',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Stagecoach Run',
#   'place': 'hamlet',
#   'pos': [36.0423631, -79.0861232],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:21Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '155',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002546',
#   'id': '157559066',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Falls of New Hope',
#   'place': 'hamlet',
#   'pos': [36.0087526, -79.0625114],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:21Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '135',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002565',
#   'id': '157559081',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Carlton Acres',
#   'place': 'hamlet',
#   'pos': [35.8829222, -79.0794562],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:26Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '177',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002537',
#   'id': '157567037',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Northwood',
#   'place': 'hamlet',
#   'pos': [35.9662535, -79.0630669],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:28Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '95',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1006055',
#   'id': '157568582',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Five Oaks',
#   'place': 'hamlet',
#   'pos': [35.942922, -78.9880651],
#   'type': 'node'},
#  {'created': {'changeset': '811941',
#    'timestamp': '2009-03-15T12:04:26Z',
#    'uid': '105614',
#    'user': 'aarona',
#    'version': '3'},
#   'created_by': 'Potlatch 0.10f',
#   'ele': '134',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002964',
#   'id': '157572553',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'name': 'Northwoods',
#   'place': 'hamlet',
#   'pos': [35.8052586, -78.7785853],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:31Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '83',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1006064',
#   'id': '157572765',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Surry Green',
#   'place': 'hamlet',
#   'pos': [35.9437559, -78.9400087],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:34Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '137',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002591',
#   'id': '157576083',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Mount Bolus',
#   'place': 'hamlet',
#   'pos': [35.9287547, -79.0522333],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:37Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '149',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002589',
#   'id': '157579711',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Quail Run',
#   'place': 'hamlet',
#   'pos': [35.953754, -79.0566779],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:40Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '90',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002577',
#   'id': '157583557',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Colony Woods',
#   'place': 'hamlet',
#   'pos': [35.9487548, -79.0080656],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:46Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '132',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002566',
#   'id': '157590164',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Southbridge',
#   'place': 'hamlet',
#   'pos': [35.8926442, -79.075845],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:51Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '112',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002532',
#   'id': '157596406',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Timbercrest',
#   'place': 'hamlet',
#   'pos': [35.9704208, -79.0105656],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:52Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '119',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002583',
#   'id': '157596422',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Clark Hills',
#   'place': 'hamlet',
#   'pos': [35.9418103, -79.0325107],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:52Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '159',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002599',
#   'id': '157597295',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Laurel Springs',
#   'place': 'hamlet',
#   'pos': [35.9409756, -79.1150127],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:48:57Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '176',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1021633',
#   'id': '157606340',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'New Hope',
#   'place': 'hamlet',
#   'pos': [36.0101413, -79.0739006],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:12Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '64',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1020212',
#   'id': '157619154',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'name': 'Falls',
#   'place': 'hamlet',
#   'pos': [35.9398724, -78.5794464],
#   'type': 'node'},
#  {'census:population': '57233;2010',
#   'created': {'changeset': '43493276',
#    'timestamp': '2016-11-08T17:11:11Z',
#    'uid': '2511706',
#    'user': 'calfarome',
#    'version': '5'},
#   'ele': '148',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1019602',
#   'id': '157619192',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Chapel Hill',
#   'place': 'town',
#   'population': '57233',
#   'pos': [35.9131996, -79.0558445],
#   'type': 'node',
#   'wikidata': 'Q671812'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:23Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '118',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1019692',
#   'id': '157626695',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'name': 'Clegg',
#   'place': 'hamlet',
#   'pos': [35.8657039, -78.8494514],
#   'type': 'node'},
#  {'created': {'changeset': '8649814',
#    'timestamp': '2011-07-06T16:30:30Z',
#    'uid': '314272',
#    'user': 'Bruce in San Diego',
#    'version': '3'},
#   'ele': '116',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002585',
#   'id': '157628814',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Estes Hills',
#   'place': 'hamlet',
#   'pos': [35.9323658, -79.0477888],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:30Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '113',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '985724',
#   'id': '157636582',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Glen Forest',
#   'place': 'hamlet',
#   'pos': [36.0220894, -78.8097283],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:30Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '166',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002590',
#   'id': '157636638',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'North Forest Hills',
#   'place': 'hamlet',
#   'pos': [35.9551429, -79.0514],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:31Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '84',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1006063',
#   'id': '157636661',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'New Hope Valley',
#   'place': 'hamlet',
#   'pos': [35.9412559, -78.9519533],
#   'type': 'node'},
#  {'created': {'changeset': '13612337',
#    'timestamp': '2012-10-24T03:19:08Z',
#    'uid': '922360',
#    'user': 'JMDeMai',
#    'version': '3'},
#   'ele': '90',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1019528',
#   'id': '157637368',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'name': 'Caraleigh',
#   'place': 'suburb',
#   'pos': [35.7606347, -78.6486338],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:41Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '119',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002595',
#   'id': '157645489',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Ironwoods',
#   'place': 'hamlet',
#   'pos': [35.9265322, -79.075845],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:42Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '90',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1019289',
#   'id': '158224225',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Briarcliff',
#   'place': 'hamlet',
#   'pos': [35.9284775, -79.015288],
#   'type': 'node'},
#  {'created': {'changeset': '8649766',
#    'timestamp': '2011-07-06T16:24:14Z',
#    'uid': '314272',
#    'user': 'Bruce in San Diego',
#    'version': '3'},
#   'ele': '155',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002529',
#   'id': '158226843',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Carol Woods',
#   'place': 'hamlet',
#   'pos': [35.9662539, -79.039733],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:45Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '155',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1020858',
#   'id': '158226885',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Huckleberry Spring',
#   'place': 'hamlet',
#   'pos': [36.0409759, -78.9580645],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:49:47Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '167',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002533',
#   'id': '158228993',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Timberlyne',
#   'place': 'hamlet',
#   'pos': [35.9620871, -79.0500111],
#   'type': 'node'},
#  {'created': {'changeset': '33382996',
#    'timestamp': '2015-08-17T07:07:09Z',
#    'uid': '2847988',
#    'user': 'jinalfoflia',
#    'version': '3'},
#   'ele': '156',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002548',
#   'id': '158231523',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Windy Hill Farm',
#   'place': 'hamlet',
#   'pos': [36.0221766, -79.0367016],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:00Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '96',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002562',
#   'id': '158245759',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Weatherhill',
#   'place': 'hamlet',
#   'pos': [35.9009772, -79.0791784],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:00Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '88',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002584',
#   'id': '158245782',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Lake Forest Estates',
#   'place': 'hamlet',
#   'pos': [35.9298661, -79.0355662],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:08Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '123',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '981477',
#   'id': '158257692',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Bilboa',
#   'place': 'hamlet',
#   'pos': [35.955979, -78.8527848],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:10Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '132',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002991',
#   'id': '158260130',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'name': 'Mount Vernon',
#   'place': 'hamlet',
#   'pos': [35.7926514, -78.724727],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:10Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '94',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002578',
#   'id': '158260699',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'The Oaks II',
#   'place': 'hamlet',
#   'pos': [35.9306999, -79.0069544],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:10Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '91',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1006343',
#   'id': '158261266',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Redwood',
#   'place': 'hamlet',
#   'pos': [36.0470898, -78.7713942],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:19Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '150',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002530',
#   'id': '158268121',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Birchwood Lake Estates',
#   'place': 'hamlet',
#   'pos': [35.9765315, -79.0272327],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:24Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '127',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002559',
#   'id': '158275295',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Lakewoods',
#   'place': 'hamlet',
#   'pos': [35.8956992, -79.1072346],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:25Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '163',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Orange',
#   'gnis:County_num': '135',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1002598',
#   'id': '158277468',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Orange,North Carolina,N.C.,NC,USA',
#   'name': 'Barrington Hills',
#   'place': 'hamlet',
#   'pos': [35.9356983, -79.0997345],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:26Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '88',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1006067',
#   'id': '158277583',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'The Downs',
#   'place': 'hamlet',
#   'pos': [35.8765351, -78.9913986],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:28Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '120',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1019536',
#   'id': '158280662',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'name': 'Carpenter',
#   'place': 'hamlet',
#   'pos': [35.8207049, -78.871674],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:30Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '97',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '991350',
#   'id': '158283786',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Oak Grove',
#   'place': 'hamlet',
#   'pos': [35.9815344, -78.8205619],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:39Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '110',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1020478',
#   'id': '158295956',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Gorman',
#   'place': 'hamlet',
#   'pos': [36.0365336, -78.8233397],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:40Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '76',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1006059',
#   'id': '158296335',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Woodberry',
#   'place': 'hamlet',
#   'pos': [35.9348669, -78.9725093],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:40Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '116',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1022367',
#   'id': '158298207',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Rocky Knoll',
#   'place': 'hamlet',
#   'pos': [36.0162559, -78.8236175],
#   'type': 'node'},
#  {'created': {'changeset': '43504195',
#    'timestamp': '2016-11-09T05:52:50Z',
#    'uid': '3272286',
#    'user': 'manings',
#    'version': '9'},
#   'ele': '152',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1019552',
#   'id': '158299712',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'is_in:continent': 'North America',
#   'is_in:country': 'USA',
#   'name': 'Cary',
#   'place': 'city',
#   'population': '136637',
#   'pos': [35.7882973, -78.7811925],
#   'type': 'node',
#   'wikidata': 'Q852665'},
#  {'created': {'changeset': '13661992',
#    'timestamp': '2012-10-28T14:33:09Z',
#    'uid': '922360',
#    'user': 'JMDeMai',
#    'version': '3'},
#   'ele': '157',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Wake',
#   'gnis:County_num': '183',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '988319',
#   'id': '158301588',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Wake,North Carolina,N.C.,NC,USA',
#   'name': 'Leesville',
#   'place': 'suburb',
#   'pos': [35.9070932, -78.7261158],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
#    'timestamp': '2008-12-06T16:50:49Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '100',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Durham',
#   'gnis:County_num': '063',
#   'gnis:ST_alpha': 'NC',
#   'gnis:ST_num': '37',
#   'gnis:id': '1006054',
#   'id': '158309203',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Durham,North Carolina,N.C.,NC,USA',
#   'name': 'Colony Park',
#   'place': 'hamlet',
#   'pos': [35.9848654, -78.9658425],
#   'type': 'node'},
#  {'created': {'changeset': '158653',
# ...
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:18Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887600',
#   'pos': [35.852554, -79.047451],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887612',
#   'pos': [35.852602, -79.047512],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887624',
#   'pos': [35.852653, -79.047598],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887640',
#   'pos': [35.852689, -79.047695],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887649',
#   'pos': [35.852708, -79.047798],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887652',
#   'pos': [35.852717, -79.047913],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887653',
#   'pos': [35.852719, -79.048058],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887654',
#   'pos': [35.852712, -79.048185],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887696',
#   'pos': [35.864638, -78.910982],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887697',
#   'pos': [35.864844, -78.910909],
#   'type': 'node'},
#  {'created': {'changeset': '23134139',
#    'timestamp': '2014-06-25T02:05:12Z',
#    'uid': '1694880',
#    'user': 'sandhill',
#    'version': '3'},
#   'id': '169887698',
#   'pos': [35.866053, -78.9104904],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887702',
#   'pos': [35.843931, -79.062708],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887703',
#   'pos': [35.8439, -79.062761],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887705',
#   'pos': [35.843801, -79.062916],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887707',
#   'pos': [35.843731, -79.063016],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887709',
#   'pos': [35.84366, -79.063112],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887711',
#   'pos': [35.843569, -79.063224],
#   'type': 'node'},
#  {'created': {'changeset': '36648014',
#    'timestamp': '2016-01-18T03:03:00Z',
#    'uid': '402624',
#    'user': 'bdiscoe',
#    'version': '3'},
#   'id': '169887713',
#   'pos': [35.8435388, -79.06334],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887757',
#   'pos': [35.860623, -79.083787],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887759',
#   'pos': [35.860762, -79.084],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887762',
#   'pos': [35.860797, -79.084052],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887894',
#   'pos': [35.860551, -79.032356],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887896',
#   'pos': [35.860563, -79.032387],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887898',
#   'pos': [35.860555, -79.03242],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887900',
#   'pos': [35.860535, -79.03246],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887902',
#   'pos': [35.860489, -79.032519],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887904',
#   'pos': [35.860428, -79.032556],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887908',
#   'pos': [35.860353, -79.032643],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887911',
#   'pos': [35.860329, -79.032676],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887913',
#   'pos': [35.860321, -79.032713],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887917',
#   'pos': [35.86033, -79.032764],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887920',
#   'pos': [35.860351, -79.032803],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887922',
#   'pos': [35.860386, -79.032851],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887924',
#   'pos': [35.860488, -79.033027],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887929',
#   'pos': [35.8462799, -79.1056133],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887935',
#   'pos': [35.8467043, -79.1055017],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887937',
#   'pos': [35.8469478, -79.1053043],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887941',
#   'pos': [35.8470522, -79.1051412],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887943',
#   'pos': [35.8470939, -79.105021],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887946',
#   'pos': [35.8470591, -79.1048494],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887950',
#   'pos': [35.8469409, -79.1045919],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887952',
#   'pos': [35.8468156, -79.1044631],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887956',
#   'pos': [35.8466556, -79.1043687],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887958',
#   'pos': [35.8464817, -79.1043001],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '169887961',
#   'pos': [35.8461825, -79.1043258],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887989',
#   'pos': [35.845232, -79.09657],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169887995',
#   'pos': [35.845359, -79.096486],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888003',
#   'pos': [35.845526, -79.096395],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888006',
#   'pos': [35.845593, -79.096364],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888012',
#   'pos': [35.845685, -79.09633],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888018',
#   'pos': [35.845853, -79.096279],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888023',
#   'pos': [35.84608, -79.096229],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888026',
#   'pos': [35.846195, -79.096211],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888029',
#   'pos': [35.846251, -79.096204],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888378',
#   'pos': [35.856385, -79.033056],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888379',
#   'pos': [35.856179, -79.033322],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888381',
#   'pos': [35.85614, -79.033397],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888390',
#   'pos': [35.856118, -79.033452],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888395',
#   'pos': [35.856084, -79.033566],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888411',
#   'pos': [35.856065, -79.033659],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888426',
#   'pos': [35.856058, -79.03373],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888428',
#   'pos': [35.856059, -79.033821],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888449',
#   'pos': [35.856069, -79.033901],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888451',
#   'pos': [35.856086, -79.03397],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888452',
#   'pos': [35.856196, -79.034224],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888457',
#   'pos': [35.856341, -79.034523],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888465',
#   'pos': [35.856467, -79.034759],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888480',
#   'pos': [35.856493, -79.034832],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888482',
#   'pos': [35.856507, -79.034899],
#   'type': 'node'},
#  {'created': {'changeset': '2442625',
#    'timestamp': '2009-09-11T05:11:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888490',
#   'pos': [35.856514, -79.035012],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888492',
#   'pos': [35.856485, -79.035185],
#   'type': 'node'},
#  {'created': {'changeset': '3355194',
#    'timestamp': '2009-12-12T12:06:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '169888494',
#   'pos': [35.856216, -79.035806],
#   'type': 'node'},
#  ...]

# %% [markdown]
# ## Data Overview with MongoDB

# %% [markdown]
# I have used the command below to insert the json data into MongoDB in my local computer

# %%
# mongoimport -h 127.0.0.1:27017 --db  openstreet_raleigh  --collection  collection  --file  raleigh_north-carolina.osm.json

# %% [markdown]
# Now let us access the stored dataset from mongodb and do different data analysis. To do that first we need to connect to the MongoDB server installed locally.

# %%
from pymongo import MongoClient
client = MongoClient('localhost:27017')
db = client.openstreet_raleigh

# %% [markdown]
# ### Checking the size of the file

# %%
import os
print 'The size of the origanal dataset {} MB'.format(os.path.getsize('raleigh_north-carolina.osm')/1.0e6) # convert from bytes to megabytes
print 'The size of the json dataset {} MB'.format(os.path.getsize('raleigh_north-carolina.osm.json')/1.0e6) # convert from bytes to megabytes
# Out:
# The size of the origanal dataset 483.230968 MB
# The size of the json dataset 558.674601 MB

# %% [markdown]
# ### How many documents in the dataset ?
#
# The result show that there are 2564349 documnets after processing the data

# %%
# let us access the json file from the collection in the database
raleigh_data_json = db.collection

# %%
raleigh_data_json.find().count()
# Out:
# 2564349

# %% [markdown]
# ### The number of nodes and ways in the dataset

# %%
print "Number of nodes:",raleigh_data_json.find({'type':'node'}).count()
print "Number of ways:",raleigh_data_json.find({'type':'way'}).count()
# Out:
# Number of nodes: 2325552
# Number of ways: 238789

# %% [markdown]
# ### Who contributes the most?
# Below is the list of the top ten contributors

# %%
result = raleigh_data_json.aggregate( [
                                        { "$group" : {"_id" : "$created.user", 
                                        "count" : { "$sum" : 1} } },
                                        { "$sort" : {"count" : -1} }, 
                                        { "$limit" : 10 } ] )

print(list(result))
# Out:
# [{u'count': 1557194, u'_id': u'jumbanho'}, {u'count': 202705, u'_id': u'JMDeMai'}, {u'count': 129883, u'_id': u'bdiscoe'}, {u'count': 114022, u'_id': u'woodpeck_fixbot'}, {u'count': 103432, u'_id': u'bigal945'}, {u'count': 66743, u'_id': u'yotann'}, {u'count': 41462, u'_id': u'runbananas'}, {u'count': 32414, u'_id': u'sandhill'}, {u'count': 30731, u'_id': u'MikeInRaleigh'}, {u'count': 21942, u'_id': u'Clay Hobbs'}]

# %% [markdown]
# ### List of top 20 cuisine in Raleigh

# %%
cuisine = raleigh_data_json.aggregate([{"$match":{"amenity":{"$exists":1},
                                 "amenity":"restaurant",}},      
                      {"$group":{"_id":{"Food":"$cuisine"},
                                 "count":{"$sum":1}}},
                      {"$project":{"_id":0,
                                  "Food":"$_id.Food",
                                  "Count":"$count"}},
                      {"$sort":{"Count":-1}}, 
                      {"$limit":20}])
print(list(cuisine))
# Out:
# [{u'Food': None, u'Count': 206}, {u'Food': u'american', u'Count': 44}, {u'Food': u'mexican', u'Count': 42}, {u'Food': u'pizza', u'Count': 40}, {u'Food': u'italian', u'Count': 30}, {u'Food': u'burger', u'Count': 27}, {u'Food': u'chinese', u'Count': 27}, {u'Food': u'sandwich', u'Count': 17}, {u'Food': u'japanese', u'Count': 16}, {u'Food': u'asian', u'Count': 16}, {u'Food': u'regional', u'Count': 15}, {u'Food': u'indian', u'Count': 10}, {u'Food': u'seafood', u'Count': 8}, {u'Food': u'thai', u'Count': 8}, {u'Food': u'greek', u'Count': 6}, {u'Food': u'barbecue', u'Count': 6}, {u'Food': u'steak_house', u'Count': 6}, {u'Food': u'sushi', u'Count': 4}, {u'Food': u'vietnamese', u'Count': 3}, {u'Food': u'french', u'Count': 3}]

# %% [markdown]
# ### List of top 10 post code in Raleigh

# %%
postcode = raleigh_data_json.aggregate( [ 
    { "$match" : { "address.postcode" : { "$exists" : 1} } }, 
    { "$group" : { "_id" : "$address.postcode", "count" : { "$sum" : 1} } },  
    { "$sort" : { "count" : -1}},
      {"$limit":10}] )
print(list(postcode))
# Out:
# [{u'count': 1612, u'_id': u'27560'}, {u'count': 904, u'_id': u'27519'}, {u'count': 721, u'_id': u'27609'}, {u'count': 687, u'_id': u'27701'}, {u'count': 526, u'_id': u'27705'}, {u'count': 432, u'_id': u'27615'}, {u'count': 328, u'_id': u'27510'}, {u'count': 236, u'_id': u'27604'}, {u'count': 190, u'_id': u'27513'}, {u'count': 182, u'_id': u'27514'}]

# %%
building = raleigh_data_json.aggregate([
       {'$match': {'building': { '$exists': 1}}}, 
        {'$group': {'_id': '$building',
                    'count': {'$sum': 1}}}, 
        {'$sort': {'count': -1}},
        {'$limit': 10}])
print(list(building))
# Out:
# [{u'count': 128500, u'_id': u'yes'}, {u'count': 9757, u'_id': u'house'}, {u'count': 9502, u'_id': u'residential'}, {u'count': 8631, u'_id': u'shed'}, {u'count': 566, u'_id': u'apartments'}, {u'count': 344, u'_id': u'detached'}, {u'count': 325, u'_id': u'commercial'}, {u'count': 190, u'_id': u'retail'}, {u'count': 159, u'_id': u'roof'}, {u'count': 136, u'_id': u'school'}]

# %% [markdown]
# ## Other ideas

# %% [markdown]
# While auditing the street names and zipcodes in the xml dataset we have wittnessed that there are a lot of street naming inconsistncies , there are also problems in the zipcode formats ,some zipcodes are not in the area, some zipcodes contain only 4 digits and others have five and with extetnsions. This could be problems that arise due to the different bodys which have contributed to the openstreet dataset. So to alleviate this problems I would suggest the following:-
#
# - To establish a standardized data inputting or reporting format that should  be comminicated to to any contributor of the dataset, such as commenly used street names and zipcodes
# - Use other data sources such as google API to augument with the data we accessed from openstreetmap which would solve missing data or also validates the present dataset.
# - Ecouraging as many people or entities to contribute to the data, as we saw above in the top contributors list, only few people or entities are contributing, the top one contributes about 1557194 and the second one contibutes about 202705, which show a big difference in contibution to the dataset.

# %% [markdown]
# #  Conclusions
#
# For this project I used data from www.openstreetmap.org for Raleigh, NC. The  dataset  was iteratelvely parsed to find out the total number of  tags contained in the XML documents. Then  I did auditing on streetname to find out if the names are consitent all over the whole document. I have found out that streetnames are not used consitently, for example 'St.', 'street'and 'St,' are used to for 'Street' , and 'Dr'/'Dr.' used for 'Drive' and soon. Later these names are upadated to the most common namings. This problem in naming inconsistency might be caused due to a number of contributor for the dataset.  After auditig and updating of the dataset was converted from XML to JSON format and imported into MongoDB data base. I have faced challenge to import into the mongodb database using the 'insert()' method of pymongo until I able to import the json data using the 'mongoimport' method direclty in the command window. Finally some data analysis was made by connecting to MongoDB and accessing the stored json data from mongodb database.

# %% [markdown]
# # Reference
#
# 1. [http://wiki.openstreetmap.org/wiki/OSM_XML](http://wiki.openstreetmap.org/wiki/OSM_XML)
# 2. [https://www.w3schools.com/xml/xml_whatis.asp](https://www.w3schools.com/xml/xml_whatis.asp)
# 3. [https://stackoverflow.com/questions/15171622/mongoimport-of-json-file](https://stackoverflow.com/questions/15171622/mongoimport-of-json-file)
# 4. [https://stackoverflow.com/questions/9805451/how-to-find-names-of-all-collections-using-pymongo](https://stackoverflow.com/questions/9805451/how-to-find-names-of-all-collections-using-pymongo)
